# %%
verbose = True
very_verbose = False
eval_ML = True
eval_community = False
eval_spectral = False
eval_all = False

import os
for dirname, _, filenames in os.walk('/kaggle/input/train-test-dataset-bot-iot'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
print("working directory:") 
# !pwd
# Out:
# working directory:
# /kaggle/working

# %%
import pandas as pd
import warnings

warnings.filterwarnings("ignore")

df_original_data = pd.read_csv("/kaggle/input/Train_Test_datasets_bot/UNSW_2018_IoT_Botnet.csv")
if verbose:
    print(df_original_data.shape)
# Out:
# (668500, 46)

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:25px; font-family:verdana; color:white;background-color:green;">
#     <a id="exploratory-data-analysis"></a>
#     📌 Second: Exploratory Data Analysis
# </div>

# %%
if verbose :
    print(list(df_original_data.columns))
if very_verbose :
    print(df_original_data.dtypes)
# Out:
# ['pkSeqID', 'stime', 'flgs', 'flgs_number', 'proto', 'proto_number', 'saddr', 'sport', 'daddr', 'dport', 'pkts', 'bytes', 'state', 'state_number', 'ltime', 'seq', 'dur', 'mean', 'stddev', 'sum', 'min', 'max', 'spkts', 'dpkts', 'sbytes', 'dbytes', 'rate', 'srate', 'drate', 'TnBPSrcIP', 'TnBPDstIP', 'TnP_PSrcIP', 'TnP_PDstIP', 'TnP_PerProto', 'TnP_Per_Dport', 'AR_P_Proto_P_SrcIP', 'AR_P_Proto_P_DstIP', 'N_IN_Conn_P_DstIP', 'N_IN_Conn_P_SrcIP', 'AR_P_Proto_P_Sport', 'AR_P_Proto_P_Dport', 'Pkts_P_State_P_Protocol_P_DestIP', 'Pkts_P_State_P_Protocol_P_SrcIP', 'attack', 'category', 'subcategory']

# %%
binary_label = 'attack'
attack_cat_label = 'category'
attack_label = 'subcategory'

binary_label_count = df_original_data[binary_label].value_counts()
attack_cat_label_count = df_original_data[attack_cat_label].value_counts()
attack_label_count = df_original_data[attack_label].value_counts()

attacks = df_original_data[binary_label].unique()
categories = df_original_data[attack_cat_label].unique()
subcategories = df_original_data[attack_label].unique()

if verbose :
    print(attacks)
    print(categories)
    print(subcategories)
# Out:
# [1 0]
# ['DDoS' 'Normal' 'Reconnaissance' 'Theft']
# ['UDP' 'Normal' 'OS_Fingerprint' 'Service_Scan' 'Data_Exfiltration'
#  'Keylogging']

# %%
import matplotlib.pyplot as plt

def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i,y[i],y[i])
        
plt.figure(figsize=(25, 5))

#plot binary label
axs = plt.subplot(1, 3, 1)
x = ['normal','attack']
y = [binary_label_count[0],binary_label_count[1]]
plt.bar(x, y)
plt.xlabel('Binary label of ton-iot dataset', fontweight='bold', color = 'black',
           fontsize='12', horizontalalignment='center')
addlabels(x, y)


#plot attack categories
axs = plt.subplot(1, 3, 2)
x = ['DDos','Reconnaissance','Theft']
y = [attack_cat_label_count[0],attack_cat_label_count[1],attack_cat_label_count[3]]
plt.bar(x,y)
plt.xlabel('Attack Categories of bot-iot dataset', fontweight='bold',
           color = 'black',
           fontsize='12', horizontalalignment='center')
addlabels(x, y)

#plot attack categories
axs = plt.subplot(1, 3, 3)
x = ['UDP','Service_Scan','OS_Fingerprint','Keylogging','Data_Exfiltration']
y = [attack_label_count[0],attack_label_count[1],attack_label_count[2],attack_label_count[3],attack_label_count[4]]
plt.bar(x,y)
plt.xlabel('Attack Subcategories of bot-iot dataset', fontweight='bold',
           color = 'black',
           fontsize='12', horizontalalignment='center')
addlabels(x, y)

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning" style="font-size:14px; font-family:verdana; color:black;background-color:light-gray;">
#     <a id="Files-directory"></a>
#     🔵➖😈➖🔵 Visualize interactions (graphs)
# </div>

# %%
import random
import networkx as nx
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import igraph as ig

def extract_graph(dataset, graph_type, label, src_addr, daddr, sport=0, dst_port=0, smac=0, dst_mac=0):

    """ Extract the graph attack according to the type we need to show

        Parameters
        ----------
        dataset: dataset, graph_type: type of graph we need to show (ip, ip + proto, or ip + mac),
        label: label of the attack, src_addr: source ip, daddr: destination ip, sport: source port,
        dst_port: destination port, smac: source mac, dst_mac: destination mac

        Returns
        -------
        graph of nodes and edges , attack_list for the type of attack found on the edge between two nodes (ip sources) ,
         attack_labels for the label of the attacks in the dataset
        """

    format_supported = True
    if graph_type == 'ip':
        dataset['source_node'] = dataset[src_addr]
        dataset['dst_node'] = dataset[daddr]
    else:
        if graph_type == 'ip_proto':
            comp_field1 = sport
            comp_field2 = dst_port
        elif graph_type == 'mac':
            comp_field1 = smac
            comp_field2 = dst_mac
        else:
            format_supported = False
        if format_supported:
            dataset['source_node'] = dataset[src_addr] + ':' + dataset[comp_field1].astype(str)
            dataset['dst_node'] = dataset[daddr] + ':' + dataset[comp_field2].astype(str)
        else:
            print('Graph type not supported :' + graph_type)

    dataset['edge'] = dataset['source_node'] + ':' + dataset['dst_node']
    dataset['edge_label'] = dataset[sport].astype(str) + ':' + dataset[dst_port].astype(str) + ':' + dataset[label].astype(str)
    graph = nx.Graph()
    # pos = nx.layout.spring_layout(graph)
    sip_list = dataset['source_node']
    dip_list = dataset['dst_node']
    ip_list = [*sip_list, *dip_list]

    graph.add_nodes_from(ip_list)
    attack_labels = dataset[label]
    edge_label_list = dataset['edge_label']

    attack_list = []

    for u, v, d in zip(sip_list, dip_list, edge_label_list):
        # graph.add_edge(u, v, label=d)
        label = d.split(':')[2]
        colors = {
            0: 'blue',
            1: 'red',
        }
        color = colors[int(label[0])]
        graph.add_edge(u, v, label=d, color=color)

    for k, v, d in graph.edges(data=True):
        attack_list.append(d['label'].split(':')[2])

    return graph, attack_list, attack_labels

def show_graph(graph):

    """ Show the graph we extracted as nodes and edges in networkx

        Parameters
        ----------
        graph : graph with nodes and edges

        Returns
        -------
        display a graph with nodes and edges using networkx
        """
    

    if(graph.number_of_nodes() > 3000):
        sampled_edges = random.sample(graph.eg, 3000)
        sampled_graph = graph.subgraph(sampled_nodes)
        plt.figure(figsize=(200, 80))
        pos = nx.layout.spring_layout(sampled_graph)
        colors = [sampled_graph[u][v]['color'] for u, v in sampled_graph.edges()]
        nx.draw_networkx(sampled_graph,edge_color=colors,pos = pos)
        plt.show()
    else:
        plt.figure(figsize=(200, 80))
        pos = nx.layout.spring_layout(graph)
        colors = [graph[u][v]['color'] for u, v in graph.edges()]
        nx.draw_networkx(graph,edge_color=colors,pos = pos)
        plt.show()
        
def show_graph2(graph):
    
    if(graph.number_of_nodes() > 3000):
        sampled_edges = random.sample(graph.edges, 3000)
        sampled_graph = graph.edge_subgraph(sampled_edges)
        G=ig.Graph.from_networkx(sampled_graph)
        N = sampled_graph.number_of_nodes()
    else:
        G=ig.Graph.from_networkx(graph)
        N = graph.number_of_nodes()
    E=[e.tuple for e in G.es]# list of edges
    layt=G.layout('fr') 
    type(layt)
    
    Xn=[layt[k][0] for k in range(N)]
    Yn=[layt[k][1] for k in range(N)]
    Xe=[]
    Ye=[]
    for e in E:
        Xe+=[layt[e[0]][0],layt[e[1]][0], None]
        Ye+=[layt[e[0]][1],layt[e[1]][1], None]

    trace1=go.Scatter(x=Xe,
                   y=Ye,
                   mode='lines',
                   line= dict(color='rgb(210,210,210)', width=1),
                   hoverinfo='none'
                   )
    trace2=go.Scatter(x=Xn,
                   y=Yn,
                   mode='markers',
                   name='ntw',
                   marker=dict(symbol='circle-dot',
                                            size=5,
                                            color='#6959CD',
                                            line=dict(color='rgb(50,50,50)', width=0.5)
                                            ),
                   hoverinfo='text'
                   )
    
    fig = go.Figure(data=[trace1, trace2],
             layout=go.Layout(
                title='<br>Graph of the network',
                titlefont_size=16,
                showlegend=False,
                hovermode='closest',
                margin=dict(b=20,l=5,r=5,t=40),
                xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                yaxis=dict(showgrid=False, zeroline=False, showticklabels=False))
                )
    fig.show()

# %%
from time import gmtime, strftime
print (strftime("%Y-%m-%d %H:%M:%S", gmtime()))
graph, attack_list, attack_labels = extract_graph(df_original_data, 'ip', 'attack', 'saddr', 'daddr',
                                                  'sport', 'dport')
print (strftime("%Y-%m-%d %H:%M:%S", gmtime()))
show_graph2(graph)
print (strftime("%Y-%m-%d %H:%M:%S", gmtime()))
# Out:
# 2025-01-23 11:22:45
# 2025-01-23 11:22:48
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a90599bd-c149-43bd-b449-b4e792b0cb9b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a90599bd-c149-43bd-b449-b4e792b0cb9b")) {                    Plotly.newPlot(                        "a90599bd-c149-43bd-b449-b4e792b0cb9b",                        [{"hoverinfo":"none","line":{"color":"rgb(210,210,210)","width":1},"mode":"lines","x":[1.9637580883097507,-1.5215119971650855,null,1.9637580883097507,3.248803943601948,null,1.9637580883097507,0.6048771414937996,null,1.9637580883097507,3.1877412480273994,null,1.9637580883097507,5.105531314380188,null,1.9637580883097507,0.3086891626897051,null,1.9637580883097507,2.3369920780618725,null,1.9637580883097507,2.8718308785326516,null,1.9637580883097507,0.032295023061948896,null,1.9637580883097507,2.380383880821618,null,1.9637580883097507,0.9449857962589734,null,1.4095747527886617,-1.5215119971650855,null,1.4095747527886617,3.248803943601948,null,1.4095747527886617,0.6048771414937996,null,1.4095747527886617,3.1877412480273994,null,1.4095747527886617,2.3026744526543745,null,1.4095747527886617,0.3086891626897051,null,1.4095747527886617,2.3369920780618725,null,1.4095747527886617,2.8718308785326516,null,1.4095747527886617,0.032295023061948896,null,1.4095747527886617,2.380383880821618,null,1.4095747527886617,0.9449857962589734,null,1.4805885517848036,-1.5215119971650855,null,1.4805885517848036,2.3026744526543745,null,1.4805885517848036,3.248803943601948,null,1.4805885517848036,0.6048771414937996,null,1.4805885517848036,3.1877412480273994,null,1.4805885517848036,0.3086891626897051,null,1.4805885517848036,2.3369920780618725,null,1.4805885517848036,2.8718308785326516,null,1.4805885517848036,0.032295023061948896,null,1.4805885517848036,2.380383880821618,null,1.4805885517848036,0.9449857962589734,null,1.882569700433257,-1.5215119971650855,null,1.882569700433257,3.248803943601948,null,1.882569700433257,0.6048771414937996,null,1.882569700433257,3.1877412480273994,null,1.882569700433257,3.554675964773758,null,1.882569700433257,4.277891757183017,null,1.882569700433257,2.3026744526543745,null,1.882569700433257,0.3086891626897051,null,1.882569700433257,2.3369920780618725,null,1.882569700433257,2.8718308785326516,null,1.882569700433257,0.032295023061948896,null,1.882569700433257,2.380383880821618,null,1.882569700433257,0.9449857962589734,null,-1.5215119971650855,0.6048771414937996,null,-1.5215119971650855,2.380383880821618,null,-1.5215119971650855,0.9449857962589734,null,-1.5215119971650855,0.032295023061948896,null,-1.5215119971650855,-3.175132681415754,null,-1.5215119971650855,-4.679215160769579,null,-1.5215119971650855,-4.127288345051523,null,-1.5215119971650855,-2.7324649580779563,null,-1.5215119971650855,-3.950696254091466,null,-1.5215119971650855,0.37880567602762016,null,-1.5215119971650855,0.34642937259892626,null,-1.5215119971650855,1.6079678773171693,null,-1.5215119971650855,-1.1428532408859249,null,-1.5215119971650855,-2.426942366282225,null,-1.5215119971650855,-3.24851983939639,null,-1.5215119971650855,-4.250784875819511,null,-1.5215119971650855,1.808227095042452,null,-1.5215119971650855,-1.3693396215023335,null,-1.5215119971650855,0.035562499849484834,null,-1.5215119971650855,0.3086891626897051,null,-1.5215119971650855,1.0101925745426115,null,-1.5215119971650855,-5.240001825162348,null,-1.5215119971650855,-5.263645091735818,null,-1.5215119971650855,-4.709840584804092,null,-1.5215119971650855,-3.6278814763117597,null,-1.5215119971650855,-0.556898913793696,null,-1.5215119971650855,-5.071341372023803,null,-1.5215119971650855,-1.1341717161427989,null,-1.5215119971650855,0.0816186096095334,null,-1.5215119971650855,-1.6696456044478805,null,-1.5215119971650855,-1.1651870668667845,null,-1.5215119 ...
# 2025-01-23 11:22:48

# %% [markdown]
# <div class="alert alert-block alert-warning" style="font-size:14px; font-family:verdana; color:black;background-color:light-gray;">
#     <a id="Files-directory"></a>
#     🔀 Transform categories to codes
# </div>

# %%
df_scores = pd.DataFrame(columns=['attack_type', 'attack_label', 'approach_name', 'classifier', 'f1_score', 'balanced_accuracy', 'MCC', 'Precision', 'Recall', 'order'])
print(type(df_scores))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:50px; font-family:verdana; color:white;background-color:green;">
#     <a id="approaches"></a>
#     📌 Approaches
# </div>

# %% [markdown]
# 'flgs_number', 'proto_number', 'pkts', 'bytes', 'state_number', 'dur',
#        'mean', 'stddev', 'sum', 'min', 'max', 'spkts', 'dpkts', 'sbytes',
#        'dbytes', 'rate', 'srate', 'drate', 'TnBPSrcIP', 'TnBPDstIP',
#        'TnP_PSrcIP', 'TnP_PDstIP', 'TnP_PerProto', 'TnP_Per_Dport',
#        'AR_P_Proto_P_SrcIP', 'AR_P_Proto_P_DstIP', 'N_IN_Conn_P_DstIP',
#        'N_IN_Conn_P_SrcIP', 'AR_P_Proto_P_Sport', 'AR_P_Proto_P_Dport',
#        'Pkts_P_State_P_Protocol_P_DestIP', 'Pkts_P_State_P_Protocol_P_SrcIP',
#        'proto_id'

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:25px; font-family:verdana; color:white;background-color:green;">
#     <a id="time-windowing-default"></a>
#     📌 Approach 5: Timewindowing with default features and spectral metrics + M5
# </div>

# %%
map_dict_1 = {
    'Normal': 0,
    'OS_Fingerprint': 1,
    'UDP': 2,
    'Keylogging': 3,
    'Service_Scan': 4,
    'Data_Exfiltration': 5  
}

# %%
import numpy as np
import math
from scipy.misc import derivative
import statistics

def metric1(spec, num_components):
    M1 = math.exp(1 / num_components) / math.exp(1)
    return M1
    
def metric2(spec, num_components):
    algebraic_conn = spec[num_components:num_components + num_components]
    mean = statistics.mean(algebraic_conn)
    return (np.exp(mean) - 1.0)

def metric3(spec, num_components):
    max_deg = spec[len(spec) - num_components:len(spec)]
    mean = statistics.mean(max_deg)
    return mean

def metric4(spec):
    x = np.arange(len(spec))
    dx = np.diff(x)
    count = 0
    for k in range(len(dx) - 1):
        if dx[k] > math.pow(10, -12):
            count += 1
    return count
    
def metric5(S):
    return sum(S)

# %%
import networkx as nx

def extract_graph(tw, src, dst, ts, edge_weight):
    g = nx.Graph()
    
    for _, row in tw.iterrows():
        src_ip = row[src]
        dst_ip = row[dst]
        weight = row[edge_weight]

        if g.has_edge(src_ip, dst_ip):
            g[src_ip][dst_ip]['weight'] += weight
        elif g.has_edge(dst_ip, src_ip):
            g[dst_ip][src_ip]['weight'] += weight
        else:
            g.add_edge(src_ip, dst_ip, weight=weight)
    l = nx.laplacian_matrix(g, weight='weight').todense()
    ev = np.linalg.eigvalsh(l)
    return g, l, np.sort(ev)

def draw_graph(g):
    pos = nx.spring_layout(g)
    nx.draw_networkx(graph, pos=pos, with_labels=True, node_color='lightblue')
    plt.title("Undirected Graph")
    plt.axis('off')
    plt.show()
    
def extract_vector_metrics(spectrum):
    # extract here
    print()
    
def plot_two_graphs(G1, G2, ts1, ts2, ev1, ev2):
    print(ts1)
    pos = nx.spring_layout(G1)
    nx.draw(G1,pos, with_labels=True, node_color='lightblue', edge_color='gray')
    edge_labels = nx.get_edge_attributes(G1, 'weight')
    nx.draw_networkx_edge_labels(G1, pos, edge_labels=edge_labels)
    plt.show()
    
    x = range(len(ev1))
    y = ev1

    plt.plot(x, y)
    plt.xlabel('index')
    plt.ylabel('eigenvalues')
    plt.title('spectrum')
    plt.show()
    
    print(ts2)
    pos = nx.spring_layout(G2)
    nx.draw(G2,pos, with_labels=True, node_color='lightblue', edge_color='gray')
    edge_labels = nx.get_edge_attributes(G2, 'weight')
    nx.draw_networkx_edge_labels(G2, pos, edge_labels=edge_labels)
    plt.show()
    
    x = range(len(ev2))
    y = ev2

    plt.plot(x, y)
    plt.xlabel('index')
    plt.ylabel('eigenvalues')
    plt.title('spectrum')
    plt.show()

# %%
include_m1 = 1
include_m2 = 1
include_m3 = 1
include_m4 = 1
include_m5 = 1

# %%
df_original_data_tmp = df_original_data.copy() 
df_original_data_tmp['weight'] = 1
df_to_sample = df_original_data_tmp.copy()
print(df_to_sample['category'].unique())

#df_to_sample = df_to_sample[(df_to_sample['category'] == 'Normal') | (df_to_sample['subcategory'] == 'Data_Exfiltration')| (df_to_sample['subcategory'] == 'OS_Fingerprint')| (df_to_sample['subcategory'] == 'UDP')| (df_to_sample['subcategory'] == 'Keylogging')]


if verbose:
    print(df_original_data_tmp.shape)

df_to_sample['datetime'] = pd.to_datetime(df_to_sample['stime'], unit='s')

df_to_sample['subcategory'] = df_to_sample['subcategory'].replace(map_dict_1)
# Extract columns
df_timeseries = df_to_sample[['stime', 'datetime', 'saddr', 'daddr', 'sport', 'dport', 'pkts', 'bytes',
                             'rate', 'attack', 'category', 'subcategory', 'weight','dur', 'mean', 'sum', 'min', 'max', 'spkts', 'dpkts', 'srate', 'drate']]
df_timeseries = df_timeseries.sort_values(by=['stime'])
# print(df[['stime', 'datetime', 'saddr', 'daddr','pkts', 'attack', 'weight']].head(50))

# Group by columns
df_timeseries = df_timeseries.groupby(['stime', 'datetime', 'saddr', 'daddr'], as_index=False).agg({
    'pkts': 'sum', 'bytes': 'sum', 'attack': 'first', 'category':'first', 'subcategory':'first',
    'rate': 'mean', 'dur': 'mean', 'mean':'mean', 'sum': 'mean', 'min': 'mean', 'max': 'mean', 'spkts': 'mean', 'srate': 'mean'
, 'drate': 'mean', 'weight':'sum'})
print(df_timeseries['subcategory'].unique())
print(df_timeseries.head(20))

if verbose:
    print(df_timeseries.shape)

df_timeseries_tmp = df_timeseries.copy()
# Out:
# ['DDoS' 'Normal' 'Reconnaissance' 'Theft']
# (668500, 51)
# [0 4 1 2 5 3]
#          stime            datetime            saddr           daddr    pkts  \
# 0   1526344032 2018-05-15 00:27:12    192.168.100.3  192.168.100.55   59453
# 1   1526344032 2018-05-15 00:27:12   192.168.100.46   192.168.100.5  119335
# 2   1526344032 2018-05-15 00:27:12    192.168.100.5   192.168.100.3   18431
# 3   1526344032 2018-05-15 00:27:12    192.168.100.6   192.168.100.3   10056
# 4   1526344032 2018-05-15 00:27:12    192.168.100.7   192.168.100.3   16326
# 5   1526344033 2018-05-15 00:27:13    192.168.100.3    13.55.154.73    3018
# 6   1526344121 2018-05-15 00:28:41    192.168.100.1   192.168.100.3       4
# 7   1526344223 2018-05-15 00:30:23    192.168.100.7   192.168.100.4      10
# 8   1526344227 2018-05-15 00:30:27  192.168.100.149  27.124.125.250       2
# 9   1526344228 2018-05-15 00:30:28    192.168.100.4   192.168.100.7      10
# 10  1526344232 2018-05-15 00:30:32  192.168.100.149   192.168.100.1       6
# 11  1526344303 2018-05-15 00:31:43    192.168.100.1  192.168.100.27       2
# 12  1526344303 2018-05-15 00:31:43   192.168.100.27   192.168.100.1       4
# 13  1526344308 2018-05-15 00:31:48   192.168.100.27   192.168.100.1       4
# 14  1526344326 2018-05-15 00:32:06  192.168.100.150   192.168.100.3      54
# 15  1526344326 2018-05-15 00:32:06  192.168.100.150   192.168.217.2       2
# 16  1526344328 2018-05-15 00:32:08  192.168.100.149   192.168.100.3      60
# 17  1526344328 2018-05-15 00:32:08  192.168.100.149   192.168.217.2       2
# 18  1526344331 2018-05-15 00:32:11  192.168.100.148   192.168.100.3      78
# 19  1526344331 2018-05-15 00:32:11  192.168.100.148   192.168.217.2       2
#
#         bytes  attack        category  subcategory         rate          dur  \
# 0    60884536       0          Normal            0    35.268291  1685.706909
# 1   116556385       0          Normal            0    23.596827  1685.706909
# 2    17131488       0          Normal            0    10.932437  1685.808960
# 3     2976576       0          Normal            0     5.963387  1686.122192
# 4      979560       0          Normal            0     9.682835  1685.973267
# 5      682915       0          Normal            0     1.796273  1679.588989
# 6         240       0          Normal            0     0.002508  1195.996582
# 7         680       0          Normal            0     0.006190  1453.945923
# 8         180       0          Normal            0    20.590960     0.048565
# 9         510       0          Normal            0     0.006189  1454.080322
# 10        360       0          Normal            0     0.003988  1253.632690
# 11        120       0          Normal            0  2724.795654     0.000367
# 12        630       0          Normal            0     0.005264   569.933960
# 13        240       0          Normal            0     0.005264   569.855957
# 14       3240       1  Reconnaissance            4     0.045994  1152.328247
# 15        172       0          Normal            0     0.399984     2.500101
# 16       3600       1  Reconnaissance            4     0.051215  1151.995850
# 17        172       0          Normal            0     0.399824     2.501101
# 18       4680       1  Reconnaissance            4     0.066787  1152.921143
# 19        172       0          Normal            0     0.399805     2.501218
#
#         mean          sum       min       max         spkts      srate  \
# 0   4.947914  1662.499146  0.768694  4.999863  29727.000000  17.634146
# 1   4.947421  1662.333455  0.710962  4.994479  29869.666667  17.718779
# 2   4.898582  1645.923340  0.598172  4.999866  18431.000000  10.932437
# 3   4.832168  1623.608521  0.655978  4.999866  10056.000000   5.963387
# 4   4.893885  1644.345215  0.655978  4.999755  16326.000000   9.682835
# 5   3.947982  1314.677856  1.516830  4.999982   1509.000000   0.897839
# 6   0.000006     0.000011  0.000004  0.000007      2.000000   0.000836
# 7   0.000028     0.000138  0.000022  0.000042      5.000000   0.002751
# 8   0.048565     0.048565  0.048565  0.048565      1.000000   0.000000
# 9   0.000238     0.001189  0.000199  0.000261      5.000000   0.002751
# 10  0.000144     0.000432  0.000115  0.000179      3.000000   0.001595
# 11  0.000367     0.000367  0.000367  0.000367      1.000000   0.000000
# 12  0.098505     0.197011  0.018356  0.178655      2.000000   0.001755
# 13  0.000122     0.000243  0.000097  0.000146      2.000000   0.001755
# 14  0.000044     0.001200  0.000002  0.000095     27.000000   0.022563
# 15  0.000000     0.000000  0.000000  0.000000      2.000000   0.399984
# 16  0.000040     0.001192  0.000008  0.000098     30.000000   0.025174
# 17  0.000000     0.000000  0.000000  0.000000      2.000000   0.399824
# 18  0.000058     0.002276  0.000006  0.000769     39.000000   0.032960
# 19  0.000000     0.000000  0.000000  0.000000      2.000000   0.399805
#
#         drate  weight
# 0   17.633553       1
# 1    5.877851       3
# 2    0.000000       1
# 3    0.000000       1
# 4    0.000000       1
# 5    0.897839       1
# 6    0.000836       1
# 7    0.002751       1
# 8    0.000000       1
# 9    0.002751       1
# 10   0.001595       1
# 11   0.000000       1
# 12   0.001755       1
# 13   0.001755       1
# 14   0.022563       1
# 15   0.000000       1
# 16   0.025174       1
# 17   0.000000       1
# 18   0.032960       1
# 19   0.000000       1
# (26775, 19)

# %%
 def get_first_value(series):
    return series.iloc[0]

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')


df = df_timeseries_tmp.copy()
df_topredict = pd.DataFrame()

df['next_stime'] = df['stime'] + 60
df['next_datetime'] = pd.to_datetime(df['next_stime'], unit='s')

count_one_min_windows = 0

for index, row in df.iterrows():
    attack_label =0
    current_timestamp = row['stime']
    next_timestamp = row['next_stime']
    mask = (df['stime'] <= next_timestamp) & (df['stime'] >= current_timestamp)
    time_window = df[mask]
    unique_time_window = time_window.iloc[:, 0].unique()
    
    if len(unique_time_window) >= 10:
        
        # print(unique_time_window)
        count_one_min_windows += 1
        
        # ts1
        ts1 = unique_time_window[len(unique_time_window) - int(len(unique_time_window)/2)]
        mask = (time_window['stime'] <= ts1) & (time_window['stime'] >= current_timestamp)
        sub_time_window = time_window[mask]
        
        g1_pkts, l1_pkts, ev1_pkts = extract_graph(sub_time_window, 'saddr', 'daddr', ts1, 'pkts')
        
        # Perform Singular Value Decomposition (SVD) on the Laplacian matrix
        U_pkts, S_pkts, Vh_pkts = np.linalg.svd(l1_pkts, full_matrices=False)
        num_components_pkts = nx.number_connected_components(g1_pkts)
        
        t1_m1_pkts = metric1(ev1_pkts, num_components_pkts)
        t1_m2_pkts = metric2(ev1_pkts, num_components_pkts)
        t1_m3_pkts = metric3(ev1_pkts, num_components_pkts)
        t1_m4_pkts = metric4(ev1_pkts[1:])
        t1_m5_pkts = metric5(S_pkts)
        
        g1_bytes, l1_bytes, ev1_bytes = extract_graph(sub_time_window, 'saddr', 'daddr', ts1, 'bytes')
        num_components_bytes = nx.number_connected_components(g1_bytes)
        
        # Perform Singular Value Decomposition (SVD) on the Laplacian matrix
        U_bytes, S_bytes, Vh_bytes = np.linalg.svd(l1_bytes, full_matrices=False)
        
        t1_m1_bytes = metric1(ev1_bytes, num_components_bytes)
        t1_m2_bytes = metric2(ev1_bytes, num_components_bytes)
        t1_m3_bytes = metric3(ev1_bytes, num_components_bytes)
        t1_m4_bytes = metric4(ev1_bytes[1:])
        t1_m5_bytes = metric5(S_bytes)
        
        g1_rate, l1_rate, ev1_rate = extract_graph(sub_time_window, 'saddr', 'daddr', ts1, 'rate')
        num_components_rate = nx.number_connected_components(g1_rate)
        
        # Perform Singular Value Decomposition (SVD) on the Laplacian matrix
        U_rate, S_rate, Vh_rate = np.linalg.svd(l1_rate, full_matrices=False)
        
        t1_m1_rate = metric1(ev1_rate, num_components_rate)
        t1_m2_rate = metric2(ev1_rate, num_components_rate)
        t1_m3_rate = metric3(ev1_rate, num_components_rate)
        t1_m4_rate = metric4(ev1_rate[1:])
        t1_m5_rate = metric5(S_rate)
        
        # ts2
        ts2 = unique_time_window[len(unique_time_window) - 1]
        mask = (time_window['stime'] <= ts2) & (time_window['stime'] >= current_timestamp)
        sub_time_window = time_window[mask]
        
        if (sub_time_window.tail(1)['subcategory'] != 0).any():
            attack_label = sub_time_window.tail(1)['subcategory'].item()
            
        
        g2_pkts, l2_pkts, ev2_pkts = extract_graph(sub_time_window, 'saddr', 'daddr', ts2, 'pkts')
        num_components_pkts = nx.number_connected_components(g2_pkts)
        
        # Perform Singular Value Decomposition (SVD) on the Laplacian matrix
        U2_pkts, S2_pkts, Vh2_pkts = np.linalg.svd(l2_pkts, full_matrices=False)
        
        t2_m1_pkts = metric1(ev1_pkts, num_components_pkts)
        t2_m2_pkts = metric2(ev1_pkts, num_components_pkts)
        t2_m3_pkts = metric3(ev1_pkts, num_components_pkts)
        t2_m4_pkts = metric4(ev1_pkts[1:])
        t2_m5_pkts = metric5(S2_pkts)
        
        g2_bytes, l2_bytes, ev2_bytes = extract_graph(sub_time_window, 'saddr', 'daddr', ts2, 'bytes')
        num_components_bytes = nx.number_connected_components(g2_bytes)

        # Perform Singular Value Decomposition (SVD) on the Laplacian matrix
        U2_bytes, S2_bytes, Vh2_bytes = np.linalg.svd(l2_bytes, full_matrices=False)
        
        t2_m1_bytes = metric1(ev2_bytes, num_components_bytes)
        t2_m2_bytes = metric2(ev2_bytes, num_components_bytes)
        t2_m3_bytes = metric3(ev2_bytes, num_components_bytes)
        t2_m4_bytes = metric4(ev2_bytes[1:])
        t2_m5_bytes = metric5(S2_bytes)
        
        g2_rate, l2_rate, ev2_rate = extract_graph(sub_time_window, 'saddr', 'daddr', ts2, 'rate')
        num_components_rate = nx.number_connected_components(g2_rate)

        # Perform Singular Value Decomposition (SVD) on the Laplacian matrix
        U2_rate, S2_rate, Vh2_rate = np.linalg.svd(l2_rate, full_matrices=False)
        
        t2_m1_rate = metric1(ev2_rate, num_components_rate)
        t2_m2_rate = metric2(ev2_rate, num_components_rate)
        t2_m3_rate = metric3(ev2_rate, num_components_rate)
        t2_m4_rate = metric4(ev2_rate[1:])
        t2_m5_rate = metric5(S2_rate)
        
        d = {}
        if include_m1:
            d['t1_m1_pkts'] = [t1_m1_pkts]
            d['t2_m1_pkts'] = [t2_m1_pkts]
            d['t1_m1_bytes'] = [t1_m1_bytes]
            d['t2_m1_bytes'] = [t2_m1_bytes]
            d['t1_m1_rate'] = [t1_m1_rate]
            d['t2_m1_rate'] = [t2_m1_rate]
            
        if include_m2:
            d['t1_m2_pkts'] = [t1_m2_pkts]
            d['t2_m2_pkts'] = [t2_m2_pkts]
            d['t1_m2_bytes'] = [t1_m2_bytes]
            d['t2_m2_bytes'] = [t2_m2_bytes]
            d['t1_m2_rate'] = [t1_m2_rate]
            d['t2_m2_rate'] = [t2_m2_rate]
            
        if include_m3:
            d['t1_m3_pkts'] = [t1_m3_pkts]
            d['t2_m3_pkts'] = [t2_m3_pkts]
            d['t1_m3_bytes'] = [t1_m3_bytes]
            d['t2_m3_bytes'] = [t2_m3_bytes]
            d['t1_m3_rate'] = [t1_m3_rate]
            d['t2_m3_rate'] = [t2_m3_rate]
            
        if include_m4:
            d['t1_m4_pkts'] = [t1_m4_pkts]
            d['t2_m4_pkts'] = [t2_m4_pkts]
            d['t1_m4_bytes'] = [t1_m4_bytes]
            d['t2_m4_bytes'] = [t2_m4_bytes]
            d['t1_m4_rate'] = [t1_m4_rate]
            d['t2_m4_rate'] = [t2_m4_rate]
            
        if include_m5:
            d['t1_m5_pkts'] = [t1_m5_pkts]
            d['t2_m5_pkts'] = [t2_m5_pkts]
            d['t1_m5_bytes'] = [t1_m5_bytes]
            d['t2_m5_bytes'] = [t2_m5_bytes]
            d['t1_m5_rate'] = [t1_m5_rate]
            d['t2_m5_rate'] = [t2_m5_rate]
            
        agg_series = sub_time_window.agg({
            'pkts': 'sum', 'bytes': 'sum', 'attack': get_first_value, 
            'rate': 'mean', 'dur': 'mean', 'mean':'mean', 'sum': 'mean', 'min': 'mean', 'max': 'mean', 'spkts': 'mean', 'srate': 'mean'
            , 'drate': 'mean', 'weight':'sum'
        })

        # Convert the series to a single-row DataFrame
        agg_row = agg_series.to_frame().transpose()
        # print(attack_label)
        agg_row['attack'] = attack_label
        
        if include_m1:
            agg_row['t1_m1_pkts'] = [t1_m1_pkts]
            agg_row['t2_m1_pkts'] = [t2_m1_pkts]
            agg_row['t1_m1_bytes'] = [t1_m1_bytes]
            agg_row['t2_m1_bytes'] = [t2_m1_bytes]
            agg_row['t1_m1_rate'] = [t1_m1_rate]
            agg_row['t2_m1_rate'] = [t2_m1_rate]
            
        if include_m2:
            agg_row['t1_m2_pkts'] = [t1_m2_pkts]
            agg_row['t2_m2_pkts'] = [t2_m2_pkts]
            agg_row['t1_m2_bytes'] = [t1_m2_bytes]
            agg_row['t2_m2_bytes'] = [t2_m2_bytes]
            agg_row['t1_m2_rate'] = [t1_m2_rate]
            agg_row['t2_m2_rate'] = [t2_m2_rate]
            
        if include_m3:
            agg_row['t1_m3_pkts'] = [t1_m3_pkts]
            agg_row['t2_m3_pkts'] = [t2_m3_pkts]
            agg_row['t1_m3_bytes'] = [t1_m3_bytes]
            agg_row['t2_m3_bytes'] = [t2_m3_bytes]
            agg_row['t1_m3_rate'] = [t1_m3_rate]
            agg_row['t2_m3_rate'] = [t2_m3_rate]
            
        if include_m4:
            agg_row['t1_m4_pkts'] = [t1_m4_pkts]
            agg_row['t2_m4_pkts'] = [t2_m4_pkts]
            agg_row['t1_m4_bytes'] = [t1_m4_bytes]
            agg_row['t2_m4_bytes'] = [t2_m4_bytes]
            agg_row['t1_m4_rate'] = [t1_m4_rate]
            agg_row['t2_m4_rate'] = [t2_m4_rate]

        if include_m5:
            agg_row['t1_m5_pkts'] = [t1_m5_pkts]
            agg_row['t2_m5_pkts'] = [t2_m5_pkts]
            agg_row['t1_m5_bytes'] = [t1_m5_bytes]
            agg_row['t2_m5_bytes'] = [t2_m5_bytes]
            agg_row['t1_m5_rate'] = [t1_m5_rate]
            agg_row['t2_m5_rate'] = [t2_m5_rate]
            
    
        # print(agg_row)
        # df_topredict = df_topredict.append(new_row, ignore_index=True)
        # Append the new row data to a list
        # new_rows_list = [new_row]

        # Concatenate the list of dictionaries into a new DataFrame
        df_topredict = pd.concat([df_topredict, agg_row], ignore_index=True)
        # print(len(df_topredict))
# print(len(df), count_one_min_windows)
# print(len(df_topredict))
print(df_topredict['attack'].unique())
print(df_topredict)
# Out:
# [4 0 1 2 3]
#           pkts     bytes  attack          rate         dur      mean  \
# 0       9943.0  684092.0       4   2881.833323  121.422950  0.005430
# 1       9943.0  684092.0       4   2881.833323  121.422950  0.005430
# 2      10121.0  695268.0       4   2090.637763   84.294046  0.003159
# 3      10313.0  708216.0       4   1036.679861   39.443936  0.001579
# 4      10313.0  708216.0       4   1036.679861   39.443936  0.001579
# ...        ...       ...     ...           ...         ...       ...
# 26474    574.0   92756.0       3  19584.809472    0.343253  0.343253
# 26475    570.0   92488.0       3  20727.913112    0.374444  0.374444
# 26476    570.0   92488.0       3  20727.913112    0.374444  0.374444
# 26477    566.0   92220.0       3  22149.065751    0.411873  0.411873
# 26478    566.0   92220.0       3  22149.065751    0.411873  0.411873
#
#             sum       min       max     spkts  ...  t1_m4_bytes  t2_m4_bytes  \
# 0      0.007358  0.003797  0.007073  4.276229  ...            9            9
# 1      0.007358  0.003797  0.007073  4.276229  ...            9            9
# 2      0.003753  0.002630  0.003697  3.394234  ...            9            9
# 3      0.001872  0.001316  0.001845  2.183091  ...            8            8
# 4      0.001872  0.001316  0.001845  2.183091  ...            8            8
# ...         ...       ...       ...       ...  ...          ...          ...
# 26474  0.343253  0.343253  0.343253  2.211601  ...            0            0
# 26475  0.374444  0.374444  0.374444  2.321747  ...            0            0
# 26476  0.374444  0.374444  0.374444  2.321747  ...            0            0
# 26477  0.411873  0.411873  0.411873  2.453922  ...            0            0
# 26478  0.411873  0.411873  0.411873  2.453922  ...            0            0
#
#        t1_m4_rate  t2_m4_rate  t1_m5_pkts  t2_m5_pkts  t1_m5_bytes  \
# 0               9           9     18274.0     19886.0    1230850.0
# 1               9           9     18274.0     19886.0    1230850.0
# 2               9           9     18402.0     20242.0    1248230.0
# 3               8           8     19486.0     20626.0    1341048.0
# 4               8           8     19486.0     20626.0    1341048.0
# ...           ...         ...         ...         ...          ...
# 26474           0           0        56.0      1148.0       3752.0
# 26475           0           0        56.0      1140.0       3752.0
# 26476           0           0        56.0      1140.0       3752.0
# 26477           0           0        48.0      1132.0       3216.0
# 26478           0           0        48.0      1132.0       3216.0
#
#        t2_m5_bytes     t1_m5_rate     t2_m5_rate
# 0        1368184.0  411549.031871  507202.664922
# 1        1368184.0  411549.031871  507202.664922
# 2        1390536.0  482181.593827  501753.063086
# 3        1416432.0  501484.568726  501753.052558
# 4        1416432.0  501484.568726  501753.052558
# ...            ...            ...            ...
# 26474     185512.0  176440.709964  940070.854660
# 26475     184976.0  175608.916994  912028.176926
# 26476     184976.0  175608.916994  912028.176926
# 26477     184440.0  149543.370118  885962.630050
# 26478     184440.0  149543.370118  885962.630050
#
# [26479 rows x 43 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import numpy as np

# Load your data (replace this with your actual data loading code)
X = df_topredict.drop('attack', axis=1)
y = df_topredict['attack']

# Convert the 'label' column to integers if it's of object type
if y.dtype == object:
    label_encoder = LabelEncoder()
    y = label_encoder.fit_transform(y)

# Handle non, infinite, and large values by setting them to 10^5
X[np.isnan(X) | np.isinf(X) | (X > 1e5)] = 1e5

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Display the shapes of the resulting datasets
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (18535, 42)
# y_train shape: (18535,)
# X_test shape: (7944, 42)
# y_test shape: (7944,)

# %%
X_train_smetrics_m5 = X_train[['t1_m1_pkts', 't1_m2_pkts', 't1_m3_pkts', 't1_m4_pkts', 't1_m5_pkts',
                   't2_m1_pkts', 't2_m2_pkts', 't2_m3_pkts', 't2_m4_pkts', 't2_m5_pkts',
                   't1_m1_bytes', 't1_m2_bytes', 't1_m3_bytes', 't1_m4_bytes', 't1_m5_bytes',
                   't2_m1_bytes', 't2_m2_bytes', 't2_m3_bytes', 't2_m4_bytes','t2_m5_bytes',
                   't1_m1_rate', 't1_m2_rate', 't1_m3_rate', 't1_m4_rate', 't1_m5_rate',
                   't2_m1_rate', 't2_m2_rate', 't2_m3_rate', 't2_m4_rate', 't2_m5_rate',
                   'pkts', 'bytes', 'rate']]
X_test_smetrics_m5 = X_test[['t1_m1_pkts', 't1_m2_pkts', 't1_m3_pkts', 't1_m4_pkts', 't1_m5_pkts',
                   't2_m1_pkts', 't2_m2_pkts', 't2_m3_pkts', 't2_m4_pkts', 't2_m5_pkts',
                   't1_m1_bytes', 't1_m2_bytes', 't1_m3_bytes', 't1_m4_bytes', 't1_m5_bytes',
                   't2_m1_bytes', 't2_m2_bytes', 't2_m3_bytes', 't2_m4_bytes','t2_m5_bytes',
                   't1_m1_rate', 't1_m2_rate', 't1_m3_rate', 't1_m4_rate', 't1_m5_rate',
                   't2_m1_rate', 't2_m2_rate', 't2_m3_rate', 't2_m4_rate', 't2_m5_rate',
                   'pkts', 'bytes', 'rate']]

# %%
X_train_smetrics = X_train[['t1_m1_pkts', 't1_m2_pkts', 't1_m3_pkts', 't1_m4_pkts',
                   't2_m1_pkts', 't2_m2_pkts', 't2_m3_pkts', 't2_m4_pkts', 
                   't1_m1_bytes', 't1_m2_bytes', 't1_m3_bytes', 't1_m4_bytes',
                   't2_m1_bytes', 't2_m2_bytes', 't2_m3_bytes', 't2_m4_bytes',
                   't1_m1_rate', 't1_m2_rate', 't1_m3_rate', 't1_m4_rate',
                   't2_m1_rate', 't2_m2_rate', 't2_m3_rate', 't2_m4_rate', 
                   'pkts', 'bytes', 'rate']]
X_test_smetrics = X_test[['t1_m1_pkts', 't1_m2_pkts', 't1_m3_pkts', 't1_m4_pkts', 
                   't2_m1_pkts', 't2_m2_pkts', 't2_m3_pkts', 't2_m4_pkts', 
                   't1_m1_bytes', 't1_m2_bytes', 't1_m3_bytes', 't1_m4_bytes', 
                   't2_m1_bytes', 't2_m2_bytes', 't2_m3_bytes', 't2_m4_bytes',
                   't1_m1_rate', 't1_m2_rate', 't1_m3_rate', 't1_m4_rate',
                   't2_m1_rate', 't2_m2_rate', 't2_m3_rate', 't2_m4_rate',
                   'pkts', 'bytes', 'rate']]

# %%
X_train_m5 = X_train[['t1_m5_pkts',
                   't2_m5_pkts',
                   't1_m5_bytes',
                   't2_m5_bytes',
                   't1_m5_rate',
                   't2_m5_rate',
                   'pkts', 'bytes', 'rate']]
X_test_m5 = X_test[['t1_m5_pkts',
                 't2_m5_pkts',
                 't1_m5_bytes',
                 't2_m5_bytes',
                 't1_m5_rate',
                 't2_m5_rate',
                 'pkts', 'bytes', 'rate']]

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

   
def plot_features(plot_data, x_feature ,y_feature, z_feature, target_label, normal_cat):

    fig = plt.figure(figsize = (8, 8))
    ax = fig.add_subplot(111, projection="3d")


    ax.set_xlabel(x_feature, size=16)
    ax.set_ylabel(y_feature, size=16)
    ax.set_zlabel(z_feature, size=16)

    ax.set_title("attack classes")

    c=['b','g','c','m','y','k','r']
    c_index=0

    for target in plot_data[target_label].unique():

        current=plot_data.loc[plot_data[target_label]==target]
        x_data=current[x_feature]
        y_data=current[y_feature]
        z_data=current[z_feature]

        if target == normal_cat:
            color='b'
        else:
            color=c[c_index%len(c)]

        # print(target+":"+color)
        ax.scatter(x_data, y_data, z_data, c=color)
        c_index=c_index+1

    plt.show()
    
    
def plot_high_gain_features(clf):
    
    x, y, z = clf.feature_importances_.argsort()[-3:][::-1]
    x_feature = df_topredict.columns.tolist()[x]
    y_feature = df_topredict.columns.tolist()[y]
    z_feature = df_topredict.columns.tolist()[z]

    plot_data= pd.DataFrame()
    plot_data.insert(0,x_feature,df_topredict[x_feature],True)
    plot_data.insert(1,y_feature,df_topredict[y_feature],True)
    plot_data.insert(2,z_feature,df_topredict[z_feature],True)
    plot_data.insert(3,attack_label,df_topredict['attack'], True) # add target 
    
    plot_features(plot_data, x_feature ,y_feature, z_feature, attack_label, 'Normal')

# %%
from xgboost import XGBClassifier

clf_m5 = XGBClassifier(tree_method="auto") # gpu_hist
clf_m5=clf_m5.fit(X_train_m5,y_train)
y_pred_m5 = clf_m5.predict(X_test_m5)

clf_smetrics = XGBClassifier(tree_method="auto") # gpu_hist
clf_smetrics=clf_smetrics.fit(X_train_smetrics,y_train)
y_pred_smetrics = clf_smetrics.predict(X_test_smetrics)

clf_smetrics_m5 = XGBClassifier(tree_method="auto") # gpu_hist
clf_smetrics_m5=clf_smetrics_m5.fit(X_train_smetrics_m5,y_train)
y_pred_smetrics_m5 = clf_smetrics_m5.predict(X_test_smetrics_m5)

plot_high_gain_features(clf_m5)
plot_high_gain_features(clf_smetrics)
plot_high_gain_features(clf_smetrics_m5)

# %%
import plotly.express as px

def plot_importance(clf, metric = 'all'):
    
    importance = pd.DataFrame()
    importance['Features'] = clf.feature_names_in_
    
    if metric == 'all' or metric == 'gain':
    
        importance['Gain'] = clf.feature_importances_
        importance = importance.sort_values(by=['Gain'],ascending=False)
        fig = px.bar(importance,x='Gain', y='Features',color ='Features',orientation ='h')
        fig.update_yaxes(categoryorder="total ascending")

        fig.show()
    
    if metric == 'all' or metric == 'weight':
        weights = clf.get_booster().get_score(importance_type='weight')
        w = []
        for elm in importance['Features']:
            try:
                w.append(weights[elm])
            except:
                w.append(0)
        importance['Weight'] = w
        importance = importance.sort_values(by=['Weight'],ascending=False)
        fig = px.bar(importance,x='Weight', y='Features',color ='Features',orientation ='h')
        fig.update_yaxes(categoryorder="total ascending")

        fig.show()
    
    if metric == 'all' or metric == 'cover':
        coverages = clf.get_booster().get_score(importance_type='cover')
        c = []
        for elm in importance['Features']:
            try:
                c.append(coverages[elm])
            except:
                c.append(0)
        importance['Coverage'] = c
        importance = importance.sort_values(by=['Coverage'],ascending=False)
        fig = px.bar(importance,x='Coverage', y='Features', color ='Features',orientation ='h')
        fig.update_yaxes(categoryorder="total ascending")

        fig.show()

print("Approach M5")
plot_importance(clf_m5, metric = 'all')
print("Approach Smetrics")
plot_importance(clf_smetrics, metric = 'all')
print("Approach Smetrics + M5")
plot_importance(clf_smetrics_m5, metric = 'all')
# Out:
# Approach M5
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="da59998d-a4b3-43c9-827b-6944950df99e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da59998d-a4b3-43c9-827b-6944950df99e")) {                    Plotly.newPlot(                        "da59998d-a4b3-43c9-827b-6944950df99e",                        [{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eGain=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"bytes","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"bytes","offsetgroup":"bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[0.2328003],"xaxis":"x","y":["bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eGain=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t1_m5_rate","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"t1_m5_rate","offsetgroup":"t1_m5_rate","orientation":"h","showlegend":true,"textposition":"auto","x":[0.19320424],"xaxis":"x","y":["t1_m5_rate"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eGain=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t1_m5_bytes","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"t1_m5_bytes","offsetgroup":"t1_m5_bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[0.122413315],"xaxis":"x","y":["t1_m5_bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eGain=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"rate","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"rate","offsetgroup":"rate","orientation":"h","showlegend":true,"textposition":"auto","x":[0.112194456],"xaxis":"x","y":["rate"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eGain=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m5_pkts","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"t2_m5_pkts","offsetgroup":"t2_m5_pkts","orientation":"h","showlegend":true,"textposition":"auto","x":[0.11147648],"xaxis":"x","y":["t2_m5_pkts"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eGain=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m5_rate","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"t2_m5_rate","offsetgroup":"t2_m5_rate","orientation":"h","showlegend":true,"textposition":"auto","x":[0.08516827],"xaxis":"x","y":["t2_m5_rate"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eGain=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t1_m5_pkts","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"t1_m5_pkts","offsetgroup":"t1_m5_pkts","orientation":"h","showlegend":true,"textposition":"auto","x":[0.076940365],"xaxis":"x","y":["t1_m5_pkts"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eGain=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m5_bytes","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"t2_m5_bytes","offsetgroup":"t2_m5_bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[0.06580259],"xaxis":"x","y":["t2_m5_bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eGain=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"pkts","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"pkts","offsetgroup":"pkts","orientation":"h","showlegend":true,"textposition":"auto","x":[0.0],"xaxis":"x","y":["pkts"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","c ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="074bd7e4-5d5c-41fd-bcd2-9526f45d1010" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("074bd7e4-5d5c-41fd-bcd2-9526f45d1010")) {                    Plotly.newPlot(                        "074bd7e4-5d5c-41fd-bcd2-9526f45d1010",                        [{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eWeight=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"rate","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"rate","offsetgroup":"rate","orientation":"h","showlegend":true,"textposition":"auto","x":[1294.0],"xaxis":"x","y":["rate"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eWeight=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m5_pkts","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"t2_m5_pkts","offsetgroup":"t2_m5_pkts","orientation":"h","showlegend":true,"textposition":"auto","x":[1036.0],"xaxis":"x","y":["t2_m5_pkts"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eWeight=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t1_m5_pkts","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"t1_m5_pkts","offsetgroup":"t1_m5_pkts","orientation":"h","showlegend":true,"textposition":"auto","x":[887.0],"xaxis":"x","y":["t1_m5_pkts"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eWeight=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t1_m5_bytes","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"t1_m5_bytes","offsetgroup":"t1_m5_bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[727.0],"xaxis":"x","y":["t1_m5_bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eWeight=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t1_m5_rate","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"t1_m5_rate","offsetgroup":"t1_m5_rate","orientation":"h","showlegend":true,"textposition":"auto","x":[414.0],"xaxis":"x","y":["t1_m5_rate"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eWeight=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m5_rate","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"t2_m5_rate","offsetgroup":"t2_m5_rate","orientation":"h","showlegend":true,"textposition":"auto","x":[413.0],"xaxis":"x","y":["t2_m5_rate"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eWeight=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m5_bytes","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"t2_m5_bytes","offsetgroup":"t2_m5_bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[371.0],"xaxis":"x","y":["t2_m5_bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eWeight=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"bytes","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"bytes","offsetgroup":"bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[223.0],"xaxis":"x","y":["bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eWeight=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"pkts","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"pkts","offsetgroup":"pkts","orientation":"h","showlegend":true,"textposition":"auto","x":[0.0],"xaxis":"x","y":["pkts"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidt ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7bc78b27-5742-4c9a-9226-9fd48c075915" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7bc78b27-5742-4c9a-9226-9fd48c075915")) {                    Plotly.newPlot(                        "7bc78b27-5742-4c9a-9226-9fd48c075915",                        [{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eCoverage=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"bytes","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"bytes","offsetgroup":"bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[453.4541320800781],"xaxis":"x","y":["bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eCoverage=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t1_m5_bytes","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"t1_m5_bytes","offsetgroup":"t1_m5_bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[227.3932647705078],"xaxis":"x","y":["t1_m5_bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eCoverage=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m5_rate","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"t2_m5_rate","offsetgroup":"t2_m5_rate","orientation":"h","showlegend":true,"textposition":"auto","x":[227.28741455078125],"xaxis":"x","y":["t2_m5_rate"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eCoverage=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t1_m5_pkts","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"t1_m5_pkts","offsetgroup":"t1_m5_pkts","orientation":"h","showlegend":true,"textposition":"auto","x":[150.86073303222656],"xaxis":"x","y":["t1_m5_pkts"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eCoverage=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t1_m5_rate","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"t1_m5_rate","offsetgroup":"t1_m5_rate","orientation":"h","showlegend":true,"textposition":"auto","x":[140.461181640625],"xaxis":"x","y":["t1_m5_rate"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eCoverage=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m5_pkts","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"t2_m5_pkts","offsetgroup":"t2_m5_pkts","orientation":"h","showlegend":true,"textposition":"auto","x":[136.85987854003906],"xaxis":"x","y":["t2_m5_pkts"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eCoverage=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"rate","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"rate","offsetgroup":"rate","orientation":"h","showlegend":true,"textposition":"auto","x":[126.61998748779297],"xaxis":"x","y":["rate"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eCoverage=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m5_bytes","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"t2_m5_bytes","offsetgroup":"t2_m5_bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[106.49246978759766],"xaxis":"x","y":["t2_m5_bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eCoverage=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"pkts","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"pkts","offsetgroup":"pkts","orientation":"h","showlegend":true,"textposition":"auto","x":[0.0],"xaxis":"x","y":["pkts"],"yaxis":"y","type":"bar"}],     ...
# Approach Smetrics
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1eac2e2e-8ffb-41f3-9331-db39fc8316b3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1eac2e2e-8ffb-41f3-9331-db39fc8316b3")) {                    Plotly.newPlot(                        "1eac2e2e-8ffb-41f3-9331-db39fc8316b3",                        [{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eGain=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m4_bytes","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"t2_m4_bytes","offsetgroup":"t2_m4_bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[0.14163536],"xaxis":"x","y":["t2_m4_bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eGain=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t1_m2_rate","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"t1_m2_rate","offsetgroup":"t1_m2_rate","orientation":"h","showlegend":true,"textposition":"auto","x":[0.13106307],"xaxis":"x","y":["t1_m2_rate"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eGain=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t1_m3_rate","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"t1_m3_rate","offsetgroup":"t1_m3_rate","orientation":"h","showlegend":true,"textposition":"auto","x":[0.11505845],"xaxis":"x","y":["t1_m3_rate"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eGain=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"rate","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"rate","offsetgroup":"rate","orientation":"h","showlegend":true,"textposition":"auto","x":[0.06555474],"xaxis":"x","y":["rate"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eGain=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t1_m4_pkts","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"t1_m4_pkts","offsetgroup":"t1_m4_pkts","orientation":"h","showlegend":true,"textposition":"auto","x":[0.06384614],"xaxis":"x","y":["t1_m4_pkts"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eGain=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m2_rate","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"t2_m2_rate","offsetgroup":"t2_m2_rate","orientation":"h","showlegend":true,"textposition":"auto","x":[0.061704602],"xaxis":"x","y":["t2_m2_rate"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eGain=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m3_rate","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"t2_m3_rate","offsetgroup":"t2_m3_rate","orientation":"h","showlegend":true,"textposition":"auto","x":[0.05656897],"xaxis":"x","y":["t2_m3_rate"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eGain=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m3_pkts","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"t2_m3_pkts","offsetgroup":"t2_m3_pkts","orientation":"h","showlegend":true,"textposition":"auto","x":[0.05510302],"xaxis":"x","y":["t2_m3_pkts"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eGain=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"bytes","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"bytes","offsetgroup":"bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[0.05421688],"xaxis":"x","y":["bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eGain ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2bfd0f0b-2a87-40ac-bc1d-ec9ea2852451" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2bfd0f0b-2a87-40ac-bc1d-ec9ea2852451")) {                    Plotly.newPlot(                        "2bfd0f0b-2a87-40ac-bc1d-ec9ea2852451",                        [{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eWeight=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"rate","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"rate","offsetgroup":"rate","orientation":"h","showlegend":true,"textposition":"auto","x":[740.0],"xaxis":"x","y":["rate"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eWeight=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t1_m3_pkts","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"t1_m3_pkts","offsetgroup":"t1_m3_pkts","orientation":"h","showlegend":true,"textposition":"auto","x":[475.0],"xaxis":"x","y":["t1_m3_pkts"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eWeight=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"pkts","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"pkts","offsetgroup":"pkts","orientation":"h","showlegend":true,"textposition":"auto","x":[436.0],"xaxis":"x","y":["pkts"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eWeight=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t1_m3_bytes","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"t1_m3_bytes","offsetgroup":"t1_m3_bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[386.0],"xaxis":"x","y":["t1_m3_bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eWeight=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"bytes","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"bytes","offsetgroup":"bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[349.0],"xaxis":"x","y":["bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eWeight=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m3_bytes","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"t2_m3_bytes","offsetgroup":"t2_m3_bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[286.0],"xaxis":"x","y":["t2_m3_bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eWeight=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m2_rate","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"t2_m2_rate","offsetgroup":"t2_m2_rate","orientation":"h","showlegend":true,"textposition":"auto","x":[286.0],"xaxis":"x","y":["t2_m2_rate"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eWeight=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m3_rate","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"t2_m3_rate","offsetgroup":"t2_m3_rate","orientation":"h","showlegend":true,"textposition":"auto","x":[265.0],"xaxis":"x","y":["t2_m3_rate"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eWeight=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m4_bytes","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"t2_m4_bytes","offsetgroup":"t2_m4_bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[253.0],"xaxis":"x","y":["t2_m4_bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eWeight=%{x}\u003cextra\u003e\u003c\u002fextra\u0 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="09e6a96d-dc85-4465-a689-d44dcd3f67fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("09e6a96d-dc85-4465-a689-d44dcd3f67fd")) {                    Plotly.newPlot(                        "09e6a96d-dc85-4465-a689-d44dcd3f67fd",                        [{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eCoverage=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m4_bytes","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"t2_m4_bytes","offsetgroup":"t2_m4_bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[529.5681762695312],"xaxis":"x","y":["t2_m4_bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eCoverage=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t1_m4_pkts","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"t1_m4_pkts","offsetgroup":"t1_m4_pkts","orientation":"h","showlegend":true,"textposition":"auto","x":[393.9702453613281],"xaxis":"x","y":["t1_m4_pkts"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eCoverage=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"bytes","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"bytes","offsetgroup":"bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[282.6773681640625],"xaxis":"x","y":["bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eCoverage=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t1_m3_pkts","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"t1_m3_pkts","offsetgroup":"t1_m3_pkts","orientation":"h","showlegend":true,"textposition":"auto","x":[180.91014099121094],"xaxis":"x","y":["t1_m3_pkts"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eCoverage=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m1_pkts","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"t2_m1_pkts","offsetgroup":"t2_m1_pkts","orientation":"h","showlegend":true,"textposition":"auto","x":[164.99826049804688],"xaxis":"x","y":["t2_m1_pkts"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eCoverage=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t1_m3_bytes","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"t1_m3_bytes","offsetgroup":"t1_m3_bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[155.92892456054688],"xaxis":"x","y":["t1_m3_bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eCoverage=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m3_bytes","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"t2_m3_bytes","offsetgroup":"t2_m3_bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[148.96246337890625],"xaxis":"x","y":["t2_m3_bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eCoverage=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m2_pkts","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"t2_m2_pkts","offsetgroup":"t2_m2_pkts","orientation":"h","showlegend":true,"textposition":"auto","x":[126.44051361083984],"xaxis":"x","y":["t2_m2_pkts"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eCoverage=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m2_rate","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"t2_m2_rate","offsetgroup":"t2_m2_rate","orientation":"h","showlegend":true,"textposition":"auto","x":[113.3082351684 ...
# Approach Smetrics + M5
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="93ab9db8-d398-4fad-86e4-e6ee30560b14" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("93ab9db8-d398-4fad-86e4-e6ee30560b14")) {                    Plotly.newPlot(                        "93ab9db8-d398-4fad-86e4-e6ee30560b14",                        [{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eGain=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m4_bytes","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"t2_m4_bytes","offsetgroup":"t2_m4_bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[0.114847764],"xaxis":"x","y":["t2_m4_bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eGain=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t1_m2_rate","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"t1_m2_rate","offsetgroup":"t1_m2_rate","orientation":"h","showlegend":true,"textposition":"auto","x":[0.10506334],"xaxis":"x","y":["t1_m2_rate"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eGain=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"bytes","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"bytes","offsetgroup":"bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[0.081268616],"xaxis":"x","y":["bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eGain=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t1_m5_rate","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"t1_m5_rate","offsetgroup":"t1_m5_rate","orientation":"h","showlegend":true,"textposition":"auto","x":[0.06530938],"xaxis":"x","y":["t1_m5_rate"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eGain=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"rate","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"rate","offsetgroup":"rate","orientation":"h","showlegend":true,"textposition":"auto","x":[0.056809116],"xaxis":"x","y":["rate"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eGain=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m3_rate","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"t2_m3_rate","offsetgroup":"t2_m3_rate","orientation":"h","showlegend":true,"textposition":"auto","x":[0.05074235],"xaxis":"x","y":["t2_m3_rate"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eGain=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t1_m4_pkts","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"t1_m4_pkts","offsetgroup":"t1_m4_pkts","orientation":"h","showlegend":true,"textposition":"auto","x":[0.050153047],"xaxis":"x","y":["t1_m4_pkts"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eGain=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t1_m3_pkts","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"t1_m3_pkts","offsetgroup":"t1_m3_pkts","orientation":"h","showlegend":true,"textposition":"auto","x":[0.048409555],"xaxis":"x","y":["t1_m3_pkts"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eGain=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t1_m3_bytes","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"t1_m3_bytes","offsetgroup":"t1_m3_bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[0.04707508],"xaxis":"x","y":["t1_m3_bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="eaaf2ea0-5bd6-46a8-9fd4-f6c63c122afd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eaaf2ea0-5bd6-46a8-9fd4-f6c63c122afd")) {                    Plotly.newPlot(                        "eaaf2ea0-5bd6-46a8-9fd4-f6c63c122afd",                        [{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eWeight=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"rate","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"rate","offsetgroup":"rate","orientation":"h","showlegend":true,"textposition":"auto","x":[624.0],"xaxis":"x","y":["rate"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eWeight=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m5_pkts","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"t2_m5_pkts","offsetgroup":"t2_m5_pkts","orientation":"h","showlegend":true,"textposition":"auto","x":[404.0],"xaxis":"x","y":["t2_m5_pkts"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eWeight=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t1_m3_pkts","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"t1_m3_pkts","offsetgroup":"t1_m3_pkts","orientation":"h","showlegend":true,"textposition":"auto","x":[318.0],"xaxis":"x","y":["t1_m3_pkts"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eWeight=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t1_m3_bytes","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"t1_m3_bytes","offsetgroup":"t1_m3_bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[258.0],"xaxis":"x","y":["t1_m3_bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eWeight=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m2_rate","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"t2_m2_rate","offsetgroup":"t2_m2_rate","orientation":"h","showlegend":true,"textposition":"auto","x":[253.0],"xaxis":"x","y":["t2_m2_rate"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eWeight=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m3_bytes","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"t2_m3_bytes","offsetgroup":"t2_m3_bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[229.0],"xaxis":"x","y":["t2_m3_bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eWeight=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m5_bytes","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"t2_m5_bytes","offsetgroup":"t2_m5_bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[225.0],"xaxis":"x","y":["t2_m5_bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eWeight=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m4_bytes","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"t2_m4_bytes","offsetgroup":"t2_m4_bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[225.0],"xaxis":"x","y":["t2_m4_bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eWeight=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t1_m5_bytes","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"t1_m5_bytes","offsetgroup":"t1_m5_bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[209.0],"xaxis":"x","y":["t1_m5_bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cbb1ae4f-7e6c-4ad5-bac4-dc53623c4347" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cbb1ae4f-7e6c-4ad5-bac4-dc53623c4347")) {                    Plotly.newPlot(                        "cbb1ae4f-7e6c-4ad5-bac4-dc53623c4347",                        [{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eCoverage=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"bytes","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"bytes","offsetgroup":"bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[675.4139404296875],"xaxis":"x","y":["bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eCoverage=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m4_bytes","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"t2_m4_bytes","offsetgroup":"t2_m4_bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[607.3954467773438],"xaxis":"x","y":["t2_m4_bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eCoverage=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t1_m4_pkts","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"t1_m4_pkts","offsetgroup":"t1_m4_pkts","orientation":"h","showlegend":true,"textposition":"auto","x":[354.10498046875],"xaxis":"x","y":["t1_m4_pkts"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eCoverage=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t1_m3_pkts","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"t1_m3_pkts","offsetgroup":"t1_m3_pkts","orientation":"h","showlegend":true,"textposition":"auto","x":[242.65097045898438],"xaxis":"x","y":["t1_m3_pkts"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eCoverage=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t1_m3_bytes","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"t1_m3_bytes","offsetgroup":"t1_m3_bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[210.56417846679688],"xaxis":"x","y":["t1_m3_bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eCoverage=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t1_m5_bytes","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"t1_m5_bytes","offsetgroup":"t1_m5_bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[197.07037353515625],"xaxis":"x","y":["t1_m5_bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eCoverage=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m3_bytes","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"t2_m3_bytes","offsetgroup":"t2_m3_bytes","orientation":"h","showlegend":true,"textposition":"auto","x":[169.8623809814453],"xaxis":"x","y":["t2_m3_bytes"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eCoverage=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t2_m1_pkts","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"t2_m1_pkts","offsetgroup":"t2_m1_pkts","orientation":"h","showlegend":true,"textposition":"auto","x":[159.32522583007812],"xaxis":"x","y":["t2_m1_pkts"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Features=%{y}\u003cbr\u003eCoverage=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"t1_m1_pkts","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"t1_m1_pkts","offsetgroup":"t1_m1_pkts","orientation":"h","showlegend":true,"textposition":"auto","x":[128.883224487 ...

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, ExtraTreesClassifier, GradientBoostingClassifier, HistGradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier

clf_names = [
    #"Nearest Neighbors",
    #"Decision Tree",
    #"Random Forest",
    #"Bagging",
    #"Extra Trees",
    #"Gradient Boosting",
    "XGBoost",
    #"MLP"#,
    #"Linear SVM",
    #"RBF SVM",
    #"Histogram-based Gradient Boosting"
]

classifiers = [#KNeighborsClassifier(3),
               #DecisionTreeClassifier(),
               #RandomForestClassifier(max_depth=3, random_state=0),
               #BaggingClassifier(n_estimators=10, random_state=0),
               # ExtraTreesClassifier(n_estimators=100, random_state=0),
               # GradientBoostingClassifier(n_estimators=100, learning_rate=1.0, max_depth=1, random_state=0),
               XGBClassifier(tree_method="auto"),
               # MLPClassifier(alpha=1, max_iter=1000)#,
               #SVC(kernel="linear", C=0.025),
               #SVC(gamma=2, C=1),
               #HistGradientBoostingClassifier()
              ]

# %%
from sklearn.metrics import balanced_accuracy_score, confusion_matrix
import numpy as np

def classwise_balanced_accuracy(y_test, pred_target, num_classes):
    class_balanced_accuracy = {}
    
    for cls in range(num_classes):
        true_positive = np.sum((y_test == cls) & (pred_target == cls))
        false_positive = np.sum((y_test != cls) & (pred_target == cls))
        true_negative = np.sum((y_test != cls) & (pred_target != cls))
        false_negative = np.sum((y_test == cls) & (pred_target != cls))
        
        sensitivity = true_positive / (true_positive + false_negative)
        specificity = true_negative / (true_negative + false_positive)
        
        balanced_accuracy = (sensitivity + specificity) / 2
        class_balanced_accuracy[cls] = balanced_accuracy
    
    return class_balanced_accuracy

# %%
from sklearn.metrics import balanced_accuracy_score, confusion_matrix
import numpy as np

def classwise_balanced_accuracy(y_test, pred_target, num_classes):
    class_balanced_accuracy = {}
    
    for cls in range(num_classes):
        true_positive = np.sum((y_test == cls) & (pred_target == cls))
        false_positive = np.sum((y_test != cls) & (pred_target == cls))
        true_negative = np.sum((y_test != cls) & (pred_target != cls))
        false_negative = np.sum((y_test == cls) & (pred_target != cls))
        
        sensitivity = true_positive / (true_positive + false_negative)
        specificity = true_negative / (true_negative + false_positive)
        
        balanced_accuracy = (sensitivity + specificity) / 2
        class_balanced_accuracy[cls] = balanced_accuracy
    
    return class_balanced_accuracy

def classwise_mcc(y_test, pred_target, num_classes):
    class_mcc = {}
    
    for cls in range(num_classes):
        true_positive = np.sum((y_test == cls) & (pred_target == cls))
        false_positive = np.sum((y_test != cls) & (pred_target == cls))
        true_negative = np.sum((y_test != cls) & (pred_target != cls))
        false_negative = np.sum((y_test == cls) & (pred_target != cls))
        
        numerator = (true_positive * true_negative) - (false_positive * false_negative)
        denominator = np.sqrt((true_positive + false_positive) * (true_positive + false_negative) * (true_negative + false_positive) * (true_negative + false_negative))
        
        # Handling the case when the denominator is zero
        if denominator == 0:
            mcc = 0
        else:
            mcc = numerator / denominator
        
        class_mcc[cls] = mcc
    
    return class_mcc

# %%
from pandas import DataFrame
from sklearn.model_selection import cross_val_score
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score, balanced_accuracy_score, matthews_corrcoef, zero_one_loss
from sklearn.metrics import classification_report, confusion_matrix

eval_df=DataFrame(columns=['Classifier',
                           'Precision',
                           'Recall',
                           'TNR',
                           'TPR',
                           'Accuracy',
                           'F1_score',
                           'Balanced_accuracy',
                           'MCC',
                           #'AUROC',
                           #'AUPRC',
                           'Error',
                           'fit_time',
                           'pred_time'])
                           #'Cross_validation_mean'])
cm_df=DataFrame(columns=['Classifier','Confusion_Matrix', 'Classification Report'])

def get_tnr_tpr(y_test, pred_target):
    
    tn=0
    tp=0
    fn=0
    fp=0

    i=0
    y_test_list=list(y_test)
    
    for i in range(len(y_test)):
        if(pred_target[i] == 0):
            if(y_test_list[i] == pred_target[i]):
                tn += 1
            else:
                fn += 1
        else:
            if(y_test_list[i] == pred_target[i]):
                tp += 1
            else:
                fp += 1

    tnr = tn/(tn+fp)
    tpr = tp/(tp+fn)

    return tnr,tpr

def get_auroc(classifier):
    
    y_proba=classifier.predict_proba(X_test)
    fpr, tpr, _ = roc_curve(y_test_bin[:, 1], y_proba[:, 1])
    return auc(fpr, tpr)

def eval_clf(classifier,y_test,pred_target, fit_time, pred_time, title):
    
    tnr, tpr = get_tnr_tpr(y_test, pred_target) 

    eval_df.loc[len(eval_df.index)] = [type(classifier).__name__.replace('Classifier',''),
                                       precision_score(y_test, pred_target, average='weighted'),
                                       recall_score(y_test, pred_target, average='weighted'),
                                       tnr,
                                       tpr,
                                       accuracy_score(y_test, pred_target),
                                       f1_score(y_test, pred_target, average='weighted'),
                                       balanced_accuracy_score(y_test, pred_target),
                                       matthews_corrcoef(y_test, pred_target),
                                       #get_auroc(classifier),
                                       #average_precision_score(y_test, pred_target),]
                                       zero_one_loss(y_test, pred_target),
                                       fit_time,
                                       pred_time]
                                       #,
                                       #cross_val_score(classifier, X, y, cv=5).mean()]
    cm_df.loc[len(eval_df.index)] = [type(classifier).__name__.replace('Classifier',''),
                                     confusion_matrix(y_test, pred_target),
                                     classification_report(y_test, pred_target)]
    
    # df_scores.loc[len(df_scores.index)] = ['DDoS', 2, 'TW (common features except t_features with smetrics)', type(classifier).__name__, classification_report(y_test, pred_target, output_dict=True).get('2')['f1-score'], 6]
    # df_scores.loc[len(df_scores.index)] = ['ScanService', 4, 'TW (common features except t_features with smetrics)', type(classifier).__name__, classification_report(y_test, pred_target, output_dict=True).get('4')['f1-score'], 6]
    # df_scores.loc[len(df_scores.index)] = ['OS Fingerprint', 1, 'TW (common features except t_features with smetrics)', type(classifier).__name__, classification_report(y_test, pred_target, output_dict=True).get('1')['f1-score'], 6]
    
    num_classes = len(np.unique(y_test))  # Assuming labels start from 0 and are continuous
    class_balanced_accuracies = classwise_balanced_accuracy(y_test, pred_target, num_classes)
    class_mcc = classwise_mcc(y_test, pred_target, num_classes)
    print(class_balanced_accuracies)
    df_scores.loc[len(df_scores.index)] = ['DDoS',
                                           2,
                                           title,
                                           type(classifier).__name__, 
                                           classification_report(y_test, pred_target, output_dict=True).get('2')['f1-score'],
                                           class_balanced_accuracies.get(2, "Class not found"),
                                           class_mcc.get(2, "Class not found"),
                                           classification_report(y_test, pred_target, output_dict=True).get('2')['precision'],
                                           classification_report(y_test, pred_target, output_dict=True).get('2')['recall'],
                                           6]
    df_scores.loc[len(df_scores.index)] = ['ScanService',
                                           4,
                                           title,
                                           type(classifier).__name__,
                                           classification_report(y_test, pred_target, output_dict=True).get('4')['f1-score'],
                                           class_balanced_accuracies.get(4, "Class not found"),
                                           class_mcc.get(4, "Class not found"),
                                           classification_report(y_test, pred_target, output_dict=True).get('4')['precision'],
                                           classification_report(y_test, pred_target, output_dict=True).get('4')['recall'],
                                           6]
    df_scores.loc[len(df_scores.index)] = ['OS Fingerprint',
                                           1,
                                           title,
                                           type(classifier).__name__,
                                           classification_report(y_test, pred_target, output_dict=True).get('1')['f1-score'],
                                           class_balanced_accuracies.get(1, "Class not found"),
                                           class_mcc.get(1, "Class not found"),
                                           classification_report(y_test, pred_target, output_dict=True).get('1')['precision'],
                                           classification_report(y_test, pred_target, output_dict=True).get('1')['recall'],
                                           6]
    df_scores.loc[len(df_scores.index)] = ['Keylogging',
                                           3,
                                           title,
                                           type(classifier).__name__,
                                           classification_report(y_test, pred_target, output_dict=True).get('3')['f1-score'],
                                           class_balanced_accuracies.get(3, "Class not found"),
                                           class_mcc.get(3, "Class not found"),
                                           classification_report(y_test, pred_target, output_dict=True).get('3')['precision'],
                                           classification_report(y_test, pred_target, output_dict=True).get('3')['recall'],
                                           6]
        
    if verbose:
        print(eval_df.columns)
        print(eval_df.loc[eval_df.Classifier==type(classifier).__name__.replace('Classifier','')])
        
def show_eval():
    print(eval_df)
    if very_verbose:
        for entry in cm_df.iterrows():
            print("Learning report for "+str(entry[0])+":")
            print(entry[1])
            #print(entry[2])

# %%
def store_eval(eval_type):
    os.chdir('/kaggle/working/')
    os.makedirs('eval/', exist_ok=True)
    eval_df.to_csv('eval/output_'+eval_type, index=False)
    cm_df.to_csv('eval/output_'+eval_type+'_report', index=False)

# %%
from datetime import datetime

if eval_ML:
    for clf in classifiers:
        print('Evaluating: ' + type(clf).__name__.replace('Classifier',''))
        print(datetime.now())
        start_time =   datetime.now()
        clf=clf.fit(X_train_m5,y_train)
        fit_time =  datetime.now() - start_time
        y_pred = clf.predict(X_test_m5)
        pred_time =  datetime.now() - start_time - fit_time
        eval_clf(clf,y_test,y_pred, fit_time, pred_time, "Approach M5")
    store_eval('numeric_only_m5')
     
    for clf in classifiers:
        print('Evaluating: ' + type(clf).__name__.replace('Classifier',''))
        print(datetime.now())
        start_time =   datetime.now()
        clf=clf.fit(X_train_smetrics,y_train)
        fit_time =  datetime.now() - start_time
        y_pred = clf.predict(X_test_smetrics)
        pred_time =  datetime.now() - start_time - fit_time
        eval_clf(clf,y_test,y_pred, fit_time, pred_time, "Approach Smetrics")
    store_eval('numeric_only_smetrics')

    for clf in classifiers:
        print('Evaluating: ' + type(clf).__name__.replace('Classifier',''))
        print(datetime.now())
        start_time =   datetime.now()
        clf=clf.fit(X_train_smetrics_m5,y_train)
        fit_time =  datetime.now() - start_time
        y_pred = clf.predict(X_test_smetrics_m5)
        pred_time =  datetime.now() - start_time - fit_time
        eval_clf(clf,y_test,y_pred, fit_time, pred_time, "Approach Smetrics + M5")
    store_eval('numeric_only_smetrics_m5')
# Out:
# Evaluating: XGB
# 2025-01-23 12:12:28.459222
# {0: 0.9576194184839044, 1: 0.9953703703703703, 2: 1.0, 3: 1.0, 4: 0.9705856902422456}
# Index(['Classifier', 'Precision', 'Recall', 'TNR', 'TPR', 'Accuracy',
#        'F1_score', 'Balanced_accuracy', 'MCC', 'Error', 'fit_time',
#        'pred_time'],
#       dtype='object')
#   Classifier  Precision    Recall       TNR       TPR  Accuracy  F1_score  \
# 0        XGB   0.995921  0.995972  0.912863  0.998572  0.995972  0.995936
#
#    Balanced_accuracy       MCC     Error               fit_time  \
# 0           0.981191  0.954198  0.004028 0 days 00:00:00.737975
#
#                pred_time
# 0 0 days 00:00:00.027683
# Evaluating: XGB
# 2025-01-23 12:12:29.444981
# {0: 0.9764992211838006, 1: 0.9907407407407407, 2: 1.0, 3: 1.0, 4: 0.9816466129304414}
# Index(['Classifier', 'Precision', 'Recall', 'TNR', 'TPR', 'Accuracy',
#        'F1_score', 'Balanced_accuracy', 'MCC', 'Error', 'fit_time',
#        'pred_time'],
#       dtype='object')
#   Classifier  Precision    Recall       TNR       TPR  Accuracy  F1_score  \
# 0        XGB   0.995921  0.995972  0.912863  0.998572  0.995972  0.995936
# 1        XGB   0.997222  0.997231  0.946281  0.998831  0.997231  0.997225
#
#    Balanced_accuracy       MCC     Error               fit_time  \
# 0           0.981191  0.954198  0.004028 0 days 00:00:00.737975
# 1           0.986892  0.968706  0.002769 0 days 00:00:00.830882
#
#                pred_time
# 0 0 days 00:00:00.027683
# 1 0 days 00:00:00.028383
# Evaluating: XGB
# 2025-01-23 12:12:30.522444
# {0: 0.978582554517134, 1: 0.9907407407407407, 2: 1.0, 3: 1.0, 4: 0.9830127331490206}
# Index(['Classifier', 'Precision', 'Recall', 'TNR', 'TPR', 'Accuracy',
#        'F1_score', 'Balanced_accuracy', 'MCC', 'Error', 'fit_time',
#        'pred_time'],
#       dtype='object')
#   Classifier  Precision    Recall       TNR       TPR  Accuracy  F1_score  \
# 0        XGB   0.995921  0.995972  0.912863  0.998572  0.995972  0.995936
# 1        XGB   0.997222  0.997231  0.946281  0.998831  0.997231  0.997225
# 2        XGB   0.997352  0.997356  0.950413  0.998831  0.997356  0.997353
#
#    Balanced_accuracy       MCC     Error               fit_time  \
# 0           0.981191  0.954198  0.004028 0 days 00:00:00.737975
# 1           0.986892  0.968706  0.002769 0 days 00:00:00.830882
# 2           0.987725  0.970162  0.002644 0 days 00:00:01.044631
#
#                pred_time
# 0 0 days 00:00:00.027683
# 1 0 days 00:00:00.028383
# 2 0 days 00:00:00.030547

# %%
if verbose:
    show_eval()
# Out:
#   Classifier  Precision    Recall       TNR       TPR  Accuracy  F1_score  \
# 0        XGB   0.995921  0.995972  0.912863  0.998572  0.995972  0.995936
# 1        XGB   0.997222  0.997231  0.946281  0.998831  0.997231  0.997225
# 2        XGB   0.997352  0.997356  0.950413  0.998831  0.997356  0.997353
#
#    Balanced_accuracy       MCC     Error               fit_time  \
# 0           0.981191  0.954198  0.004028 0 days 00:00:00.737975
# 1           0.986892  0.968706  0.002769 0 days 00:00:00.830882
# 2           0.987725  0.970162  0.002644 0 days 00:00:01.044631
#
#                pred_time
# 0 0 days 00:00:00.027683
# 1 0 days 00:00:00.028383
# 2 0 days 00:00:00.030547

# %%
import plotly.express as px
import re

def plot_evals(results_path, metrics = ["TNR", "TPR", "Precision", "Recall", "F1_score", "Accuracy", "Balanced_accuracy", "MCC"]):
    eval_df = pd.read_csv(results_path)
    # ordering columns
    col_order = ["Classifier"] + metrics
    eval_df = eval_df[col_order]
    # Melt the dataframe to convert the metrics into a single column
    melted_df = pd.melt(eval_df, id_vars=['Classifier'], var_name='Metric', value_name='Value')

    # selecting only the desired metrics
    melted_df = melted_df[melted_df['Metric'].isin(metrics)]

    # Create the bar chart
    fig = px.bar(melted_df, x='Classifier', y='Value', color='Metric', barmode='group', hover_data={"Metric":True,
                                                                                                    "Classifier":False,
                                                                                                    "Value":True})
    
    # Update the layout
    fig.update_layout(title='Evaluation Metrics by Classifier',
                    xaxis_title='Classifier',
                    yaxis_title='Value',
                    hovermode='x unified',
                )

    # Show the chart
    fig.show()
    
    
def plot_fit_pred_time(results_path):
    eval_df = pd.read_csv(results_path)
    
    # Melt the dataframe to convert the metrics into a single column
    melted_df = pd.melt(eval_df[["Classifier", "fit_time", "pred_time"]], id_vars=['Classifier'], var_name='Time', value_name='Value')
    melted_df["Value"] = pd.to_timedelta(melted_df["Value"])
    melted_df['Value'] = melted_df['Value'].dt.total_seconds()
    fig = px.bar(melted_df, x="Classifier", y="Value", color='Time', barmode='group', hover_data={"Time":True,
                                                                                                "Classifier":False,
                                                                                                "Value":True})
    # Update the layout
    fig.update_layout(title='Training and prediction time by Classifier',
                     xaxis_title='Classifier',
                     yaxis_title='Time in seconds',
                     hovermode='x unified')
    fig.update_traces(hovertemplate='%{y:.2f}s')
    
    fig.show()
    

def plot_confusion_matrixes(results_report_path):
    df = pd.read_csv(results_report_path)
    print(df)
    for row in df.itertuples():
        matrix = row.Confusion_Matrix
        
        # erasing the starting spaces at the beginning of a bracket
        matrix = re.sub(r"\[\s+", "[", matrix)

        # replace the spaces between closing and opening bracket by a comma
        matrix = re.sub(r"]\s+\[", "],[", matrix)  
        
        # replace all series of spaces by a comma
        matrix = re.sub(r"\s+", ",", matrix)

        # convert the string to a numpy array
        confusion_matrix = np.array(eval(matrix))

        # in case of imbalanced data, search for the nth highest value in the confusion matrix to be the highest scale
        n=2
        nth_max = confusion_matrix.flatten()
        nth_max.sort()
        nth_max = nth_max[-n]
        fig = px.imshow(confusion_matrix, height=800,
                width=800,
                text_auto=True,
                title=f"{row.Classifier}: Confusion matrix",
                color_continuous_scale='Blues',
                range_color=[0, nth_max]) # to use with Y = attack_cat
        fig.update_layout(xaxis_title="Predicted label",
                    yaxis_title="True label")

        fig.show()

# %%
print("Approach M5")
plot_evals('/kaggle/working/eval/output_numeric_only_m5')
plot_fit_pred_time('/kaggle/working/eval/output_numeric_only_m5')
print("Approach Smetrics")
plot_evals('/kaggle/working/eval/output_numeric_only_smetrics')
plot_fit_pred_time('/kaggle/working/eval/output_numeric_only_smetrics')
print("Approach Smetrics + M5")
plot_evals('/kaggle/working/eval/output_numeric_only_smetrics_m5')
plot_fit_pred_time('/kaggle/working/eval/output_numeric_only_smetrics_m5')
# Out:
# Approach M5
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="71fda5d3-2db4-4863-ae01-b00ff5575455" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("71fda5d3-2db4-4863-ae01-b00ff5575455")) {                    Plotly.newPlot(                        "71fda5d3-2db4-4863-ae01-b00ff5575455",                        [{"alignmentgroup":"True","customdata":[["TNR"]],"hovertemplate":"Metric=%{customdata[0]}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TNR","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"TNR","offsetgroup":"TNR","orientation":"v","showlegend":true,"textposition":"auto","x":["XGB"],"xaxis":"x","y":[0.9128630705394192],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["TPR"]],"hovertemplate":"Metric=%{customdata[0]}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TPR","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"TPR","offsetgroup":"TPR","orientation":"v","showlegend":true,"textposition":"auto","x":["XGB"],"xaxis":"x","y":[0.998571984940932],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["Precision"]],"hovertemplate":"Metric=%{customdata[0]}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Precision","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Precision","offsetgroup":"Precision","orientation":"v","showlegend":true,"textposition":"auto","x":["XGB"],"xaxis":"x","y":[0.9959213373424196],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["Recall"]],"hovertemplate":"Metric=%{customdata[0]}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Recall","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Recall","offsetgroup":"Recall","orientation":"v","showlegend":true,"textposition":"auto","x":["XGB"],"xaxis":"x","y":[0.9959718026183284],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["F1_score"]],"hovertemplate":"Metric=%{customdata[0]}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"F1_score","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"F1_score","offsetgroup":"F1_score","orientation":"v","showlegend":true,"textposition":"auto","x":["XGB"],"xaxis":"x","y":[0.9959355546310344],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["Accuracy"]],"hovertemplate":"Metric=%{customdata[0]}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Accuracy","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Accuracy","offsetgroup":"Accuracy","orientation":"v","showlegend":true,"textposition":"auto","x":["XGB"],"xaxis":"x","y":[0.9959718026183284],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["Balanced_accuracy"]],"hovertemplate":"Metric=%{customdata[0]}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Balanced_accuracy","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Balanced_accuracy","offsetgroup":"Balanced_accuracy","orientation":"v","showlegend":true,"textposition":"auto","x":["XGB"],"xaxis":"x","y":[0.9811911674144452],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["MCC"]],"hovertemplate":"Metric=%{customdata[0]}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MCC","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"MCC","offsetgroup":"MCC","orientation":"v","showlegend":true,"textposition":"auto","x":["XGB"],"xaxis":"x","y":[0.9541982590768524],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[ ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3f95a0aa-2b75-4c01-8a28-9792cee72ed0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f95a0aa-2b75-4c01-8a28-9792cee72ed0")) {                    Plotly.newPlot(                        "3f95a0aa-2b75-4c01-8a28-9792cee72ed0",                        [{"alignmentgroup":"True","customdata":[["fit_time"]],"hovertemplate":"%{y:.2f}s","legendgroup":"fit_time","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"fit_time","offsetgroup":"fit_time","orientation":"v","showlegend":true,"textposition":"auto","x":["XGB"],"xaxis":"x","y":[0.737975],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pred_time"]],"hovertemplate":"%{y:.2f}s","legendgroup":"pred_time","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"pred_time","offsetgroup":"pred_time","orientation":"v","showlegend":true,"textposition":"auto","x":["XGB"],"xaxis":"x","y":[0.027683],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":"" ...
# Approach Smetrics
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="20dd2616-b1c4-4dad-96f7-067b5e4af8c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("20dd2616-b1c4-4dad-96f7-067b5e4af8c8")) {                    Plotly.newPlot(                        "20dd2616-b1c4-4dad-96f7-067b5e4af8c8",                        [{"alignmentgroup":"True","customdata":[["TNR"],["TNR"]],"hovertemplate":"Metric=%{customdata[0]}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TNR","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"TNR","offsetgroup":"TNR","orientation":"v","showlegend":true,"textposition":"auto","x":["XGB","XGB"],"xaxis":"x","y":[0.9128630705394192,0.9462809917355371],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["TPR"],["TPR"]],"hovertemplate":"Metric=%{customdata[0]}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TPR","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"TPR","offsetgroup":"TPR","orientation":"v","showlegend":true,"textposition":"auto","x":["XGB","XGB"],"xaxis":"x","y":[0.998571984940932,0.9988314723448456],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["Precision"],["Precision"]],"hovertemplate":"Metric=%{customdata[0]}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Precision","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Precision","offsetgroup":"Precision","orientation":"v","showlegend":true,"textposition":"auto","x":["XGB","XGB"],"xaxis":"x","y":[0.9959213373424196,0.9972219572125652],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["Recall"],["Recall"]],"hovertemplate":"Metric=%{customdata[0]}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Recall","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Recall","offsetgroup":"Recall","orientation":"v","showlegend":true,"textposition":"auto","x":["XGB","XGB"],"xaxis":"x","y":[0.9959718026183284,0.9972306143001008],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["F1_score"],["F1_score"]],"hovertemplate":"Metric=%{customdata[0]}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"F1_score","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"F1_score","offsetgroup":"F1_score","orientation":"v","showlegend":true,"textposition":"auto","x":["XGB","XGB"],"xaxis":"x","y":[0.9959355546310344,0.9972245362004144],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["Accuracy"],["Accuracy"]],"hovertemplate":"Metric=%{customdata[0]}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Accuracy","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Accuracy","offsetgroup":"Accuracy","orientation":"v","showlegend":true,"textposition":"auto","x":["XGB","XGB"],"xaxis":"x","y":[0.9959718026183284,0.9972306143001008],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["Balanced_accuracy"],["Balanced_accuracy"]],"hovertemplate":"Metric=%{customdata[0]}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Balanced_accuracy","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Balanced_accuracy","offsetgroup":"Balanced_accuracy","orientation":"v","showlegend":true,"textposition":"auto","x":["XGB","XGB"],"xaxis":"x","y":[0.9811911674144452,0.9868920999384184],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["MCC"],["MCC"]],"hovertemplate":"Metric=%{customdata[0]}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MCC","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"MCC","offsetgroup":"MCC","orientation":"v","showlegend" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ea48ddd1-1cb3-49e5-831a-b3c1f0553a09" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea48ddd1-1cb3-49e5-831a-b3c1f0553a09")) {                    Plotly.newPlot(                        "ea48ddd1-1cb3-49e5-831a-b3c1f0553a09",                        [{"alignmentgroup":"True","customdata":[["fit_time"],["fit_time"]],"hovertemplate":"%{y:.2f}s","legendgroup":"fit_time","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"fit_time","offsetgroup":"fit_time","orientation":"v","showlegend":true,"textposition":"auto","x":["XGB","XGB"],"xaxis":"x","y":[0.737975,0.830882],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pred_time"],["pred_time"]],"hovertemplate":"%{y:.2f}s","legendgroup":"pred_time","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"pred_time","offsetgroup":"pred_time","orientation":"v","showlegend":true,"textposition":"auto","x":["XGB","XGB"],"xaxis":"x","y":[0.027683,0.028383],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterp ...
# Approach Smetrics + M5
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="febcad76-34ad-45ac-910b-47cd1194c858" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("febcad76-34ad-45ac-910b-47cd1194c858")) {                    Plotly.newPlot(                        "febcad76-34ad-45ac-910b-47cd1194c858",                        [{"alignmentgroup":"True","customdata":[["TNR"],["TNR"],["TNR"]],"hovertemplate":"Metric=%{customdata[0]}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TNR","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"TNR","offsetgroup":"TNR","orientation":"v","showlegend":true,"textposition":"auto","x":["XGB","XGB","XGB"],"xaxis":"x","y":[0.9128630705394192,0.9462809917355371,0.950413223140496],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["TPR"],["TPR"],["TPR"]],"hovertemplate":"Metric=%{customdata[0]}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TPR","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"TPR","offsetgroup":"TPR","orientation":"v","showlegend":true,"textposition":"auto","x":["XGB","XGB","XGB"],"xaxis":"x","y":[0.998571984940932,0.9988314723448456,0.9988314723448456],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["Precision"],["Precision"],["Precision"]],"hovertemplate":"Metric=%{customdata[0]}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Precision","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Precision","offsetgroup":"Precision","orientation":"v","showlegend":true,"textposition":"auto","x":["XGB","XGB","XGB"],"xaxis":"x","y":[0.9959213373424196,0.9972219572125652,0.9973523529468938],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["Recall"],["Recall"],["Recall"]],"hovertemplate":"Metric=%{customdata[0]}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Recall","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Recall","offsetgroup":"Recall","orientation":"v","showlegend":true,"textposition":"auto","x":["XGB","XGB","XGB"],"xaxis":"x","y":[0.9959718026183284,0.9972306143001008,0.997356495468278],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["F1_score"],["F1_score"],["F1_score"]],"hovertemplate":"Metric=%{customdata[0]}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"F1_score","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"F1_score","offsetgroup":"F1_score","orientation":"v","showlegend":true,"textposition":"auto","x":["XGB","XGB","XGB"],"xaxis":"x","y":[0.9959355546310344,0.9972245362004144,0.9973530839871227],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["Accuracy"],["Accuracy"],["Accuracy"]],"hovertemplate":"Metric=%{customdata[0]}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Accuracy","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Accuracy","offsetgroup":"Accuracy","orientation":"v","showlegend":true,"textposition":"auto","x":["XGB","XGB","XGB"],"xaxis":"x","y":[0.9959718026183284,0.9972306143001008,0.997356495468278],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["Balanced_accuracy"],["Balanced_accuracy"],["Balanced_accuracy"]],"hovertemplate":"Metric=%{customdata[0]}\u003cbr\u003eValue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Balanced_accuracy","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Balanced_accuracy","offsetgroup":"Balanced_accuracy","orientation":"v","showlegend":true,"textposition":"auto","x":["XGB","XGB","XGB"],"xaxis":"x","y":[0.9811911674144452,0.9868920999384184,0.9877254332717516],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b9a2017d-2f3c-4af6-a437-33d62612aea7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9a2017d-2f3c-4af6-a437-33d62612aea7")) {                    Plotly.newPlot(                        "b9a2017d-2f3c-4af6-a437-33d62612aea7",                        [{"alignmentgroup":"True","customdata":[["fit_time"],["fit_time"],["fit_time"]],"hovertemplate":"%{y:.2f}s","legendgroup":"fit_time","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"fit_time","offsetgroup":"fit_time","orientation":"v","showlegend":true,"textposition":"auto","x":["XGB","XGB","XGB"],"xaxis":"x","y":[0.737975,0.830882,1.044631],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[["pred_time"],["pred_time"],["pred_time"]],"hovertemplate":"%{y:.2f}s","legendgroup":"pred_time","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"pred_time","offsetgroup":"pred_time","orientation":"v","showlegend":true,"textposition":"auto","x":["XGB","XGB","XGB"],"xaxis":"x","y":[0.027683,0.028383,0.030547],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewi ...

# %%
counts = df_topredict['attack'].value_counts()

print(counts)

map_dict = {
    'Normal': 0,
    'OS_Fingerprint': 1,
    'UDP': 2,
    'Keylogging': 3,
    'Service_Scan': 4,
    'Data_Exfiltration': 5  
}

# Swap the keys and values in the map_dict
reverse_map_dict = {v: k for k, v in map_dict.items()}

# Map the numeric labels to their string labels
mapped_labels = {reverse_map_dict[key]: value for key, value in counts.items()}

print(mapped_labels)
# Out:
# attack
# 4    25223
# 0      827
# 1      376
# 3       37
# 2       16
# Name: count, dtype: int64
# {'Service_Scan': 25223, 'Normal': 827, 'OS_Fingerprint': 376, 'Keylogging': 37, 'UDP': 16}

# %%
print("Approach M5")
plot_confusion_matrixes("eval/output_numeric_only_m5_report")
print("Approach Smetrics")
plot_confusion_matrixes("eval/output_numeric_only_smetrics_report")
print("Approach Smetrics + M5")
plot_confusion_matrixes("eval/output_numeric_only_smetrics_m5_report")
# Out:
# Approach M5
#   Classifier                                   Confusion_Matrix  \
# 0        XGB  [[ 220    0    0    0   20]\n [   0  107    0 ...
#
#                                Classification Report
# 0                precision    recall  f1-score   ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f56247e0-782c-4e6e-84f5-40f639dcbc09" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f56247e0-782c-4e6e-84f5-40f639dcbc09")) {                    Plotly.newPlot(                        "f56247e0-782c-4e6e-84f5-40f639dcbc09",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","z":[[220,0,0,0,20],[0,107,0,0,1],[0,0,6,0,0],[0,0,0,12,0],[11,0,0,0,7567]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ecolor: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0, ...
# Approach Smetrics
#   Classifier                                   Confusion_Matrix  \
# 0        XGB  [[ 220    0    0    0   20]\n [   0  107    0 ...
# 1        XGB  [[ 229    0    0    0   11]\n [   0  106    0 ...
#
#                                Classification Report
# 0                precision    recall  f1-score   ...
# 1                precision    recall  f1-score   ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="82ca3d16-617e-40a6-b2fc-3f9f9cde8a45" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82ca3d16-617e-40a6-b2fc-3f9f9cde8a45")) {                    Plotly.newPlot(                        "82ca3d16-617e-40a6-b2fc-3f9f9cde8a45",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","z":[[220,0,0,0,20],[0,107,0,0,1],[0,0,6,0,0],[0,0,0,12,0],[11,0,0,0,7567]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ecolor: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0, ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5c7c166b-b62d-442b-87d8-59797a4a66db" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c7c166b-b62d-442b-87d8-59797a4a66db")) {                    Plotly.newPlot(                        "5c7c166b-b62d-442b-87d8-59797a4a66db",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","z":[[229,0,0,0,11],[0,106,0,0,2],[0,0,6,0,0],[0,0,0,12,0],[9,0,0,0,7569]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ecolor: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0," ...
# Approach Smetrics + M5
#   Classifier                                   Confusion_Matrix  \
# 0        XGB  [[ 220    0    0    0   20]\n [   0  107    0 ...
# 1        XGB  [[ 229    0    0    0   11]\n [   0  106    0 ...
# 2        XGB  [[ 230    0    0    0   10]\n [   0  106    0 ...
#
#                                Classification Report
# 0                precision    recall  f1-score   ...
# 1                precision    recall  f1-score   ...
# 2                precision    recall  f1-score   ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="27fabc0f-5a07-47e4-b198-dd8b555a1ff7" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27fabc0f-5a07-47e4-b198-dd8b555a1ff7")) {                    Plotly.newPlot(                        "27fabc0f-5a07-47e4-b198-dd8b555a1ff7",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","z":[[220,0,0,0,20],[0,107,0,0,1],[0,0,6,0,0],[0,0,0,12,0],[11,0,0,0,7567]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ecolor: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0, ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="95966f1c-d1b4-4dd3-9d80-16d1f886726a" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("95966f1c-d1b4-4dd3-9d80-16d1f886726a")) {                    Plotly.newPlot(                        "95966f1c-d1b4-4dd3-9d80-16d1f886726a",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","z":[[229,0,0,0,11],[0,106,0,0,2],[0,0,6,0,0],[0,0,0,12,0],[9,0,0,0,7569]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ecolor: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0," ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="95085d7d-2edc-482c-833e-46a2f54302e3" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("95085d7d-2edc-482c-833e-46a2f54302e3")) {                    Plotly.newPlot(                        "95085d7d-2edc-482c-833e-46a2f54302e3",                        [{"coloraxis":"coloraxis","name":"0","texttemplate":"%{z}","z":[[230,0,0,0,10],[0,106,0,0,2],[0,0,6,0,0],[0,0,0,12,0],[9,0,0,0,7569]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003ecolor: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0," ...

# %%
print(df_scores)
# Out:
#        attack_type  attack_label           approach_name     classifier  \
# 0             DDoS             2             Approach M5  XGBClassifier
# 1      ScanService             4             Approach M5  XGBClassifier
# 2   OS Fingerprint             1             Approach M5  XGBClassifier
# 3       Keylogging             3             Approach M5  XGBClassifier
# 4             DDoS             2       Approach Smetrics  XGBClassifier
# 5      ScanService             4       Approach Smetrics  XGBClassifier
# 6   OS Fingerprint             1       Approach Smetrics  XGBClassifier
# 7       Keylogging             3       Approach Smetrics  XGBClassifier
# 8             DDoS             2  Approach Smetrics + M5  XGBClassifier
# 9      ScanService             4  Approach Smetrics + M5  XGBClassifier
# 10  OS Fingerprint             1  Approach Smetrics + M5  XGBClassifier
# 11      Keylogging             3  Approach Smetrics + M5  XGBClassifier
#
#     f1_score  balanced_accuracy       MCC  Precision    Recall  order
# 0   1.000000           1.000000  1.000000   1.000000  1.000000      6
# 1   0.997890           0.970586  0.953670   0.997232  0.998548      6
# 2   0.995349           0.995370  0.995296   1.000000  0.990741      6
# 3   1.000000           1.000000  1.000000   1.000000  1.000000      6
# 4   1.000000           1.000000  1.000000   1.000000  1.000000      6
# 5   0.998549           0.981647  0.968345   0.998285  0.998812      6
# 6   0.990654           0.990741  0.990571   1.000000  0.981481      6
# 7   1.000000           1.000000  1.000000   1.000000  1.000000      6
# 8   1.000000           1.000000  1.000000   1.000000  1.000000      6
# 9   0.998615           0.983013  0.969817   0.998417  0.998812      6
# 10  0.990654           0.990741  0.990571   1.000000  0.981481      6
# 11  1.000000           1.000000  1.000000   1.000000  1.000000      6

# %%
import plotly.graph_objects as go
import pandas as pd

# Define groups based on the approach names
group_labels = df_scores["approach_name"].unique()
metrics = ["f1_score", "balanced_accuracy", "MCC"]

# Create traces for each metric group
fig = go.Figure()

for approach in group_labels:
    filtered_df = df_scores[df_scores["approach_name"] == approach]
    for metric in metrics:
        fig.add_trace(go.Scatter(
            x=filtered_df["attack_type"],
            y=filtered_df[metric],
            mode='lines+markers+text',
            text=[f'{val:.4f}' for val in filtered_df[metric]],
            textposition='top center',
            name=f"{approach}_{metric}"
        ))

# Customize the layout
fig.update_layout(
    title='Comparison of Different Feature Metrics Across Approaches',
    xaxis_title='Attack Type',
    yaxis_title='Score',
    legend_title='Metrics',
    template='plotly_white'
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c85cbe7c-404b-46cd-88bd-f2410a712f61" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c85cbe7c-404b-46cd-88bd-f2410a712f61")) {                    Plotly.newPlot(                        "c85cbe7c-404b-46cd-88bd-f2410a712f61",                        [{"mode":"lines+markers+text","name":"Approach M5_f1_score","text":["1.0000","0.9979","0.9953","1.0000"],"textposition":"top center","x":["DDoS","ScanService","OS Fingerprint","Keylogging"],"y":[1.0,0.9978900171436106,0.9953488372093023,1.0],"type":"scatter"},{"mode":"lines+markers+text","name":"Approach M5_balanced_accuracy","text":["1.0000","0.9706","0.9954","1.0000"],"textposition":"top center","x":["DDoS","ScanService","OS Fingerprint","Keylogging"],"y":[1.0,0.9705856902422456,0.9953703703703703,1.0],"type":"scatter"},{"mode":"lines+markers+text","name":"Approach M5_MCC","text":["1.0000","0.9537","0.9953","1.0000"],"textposition":"top center","x":["DDoS","ScanService","OS Fingerprint","Keylogging"],"y":[1.0,0.9536695048499687,0.9952960978391929,1.0],"type":"scatter"},{"mode":"lines+markers+text","name":"Approach Smetrics_f1_score","text":["1.0000","0.9985","0.9907","1.0000"],"textposition":"top center","x":["DDoS","ScanService","OS Fingerprint","Keylogging"],"y":[1.0,0.9985488126649076,0.9906542056074767,1.0],"type":"scatter"},{"mode":"lines+markers+text","name":"Approach Smetrics_balanced_accuracy","text":["1.0000","0.9816","0.9907","1.0000"],"textposition":"top center","x":["DDoS","ScanService","OS Fingerprint","Keylogging"],"y":[1.0,0.9816466129304414,0.9907407407407407,1.0],"type":"scatter"},{"mode":"lines+markers+text","name":"Approach Smetrics_MCC","text":["1.0000","0.9683","0.9906","1.0000"],"textposition":"top center","x":["DDoS","ScanService","OS Fingerprint","Keylogging"],"y":[1.0,0.9683451329712431,0.990571067447618,1.0],"type":"scatter"},{"mode":"lines+markers+text","name":"Approach Smetrics + M5_f1_score","text":["1.0000","0.9986","0.9907","1.0000"],"textposition":"top center","x":["DDoS","ScanService","OS Fingerprint","Keylogging"],"y":[1.0,0.9986146843459331,0.9906542056074767,1.0],"type":"scatter"},{"mode":"lines+markers+text","name":"Approach Smetrics + M5_balanced_accuracy","text":["1.0000","0.9830","0.9907","1.0000"],"textposition":"top center","x":["DDoS","ScanService","OS Fingerprint","Keylogging"],"y":[1.0,0.9830127331490206,0.9907407407407407,1.0],"type":"scatter"},{"mode":"lines+markers+text","name":"Approach Smetrics + M5_MCC","text":["1.0000","0.9698","0.9906","1.0000"],"textposition":"top center","x":["DDoS","ScanService","OS Fingerprint","Keylogging"],"y":[1.0,0.9698171453917405,0.990571067447618,1.0],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555 ...
